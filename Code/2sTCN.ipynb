# %% [markdown]
# # Gesture Recognition using Two-Stream Temporal Convolutional Network (2S-TCN)
#
# **2S-TCN** is a lightweight, fast model designed for recognizing gestures by learning temporal patterns in skeleton sequences. It uses 1D temporal convolutions to capture motion over time and integrates a **dual-stream** architecture: one stream for raw **joint** coordinates and another for **bone** vectors (relative motion between joints). This enhances its understanding of movement dynamics, but it lacks spatial awareness across joints, which can lead to confusion between similar actions.
#
# This project supports gesture-based communication between humans and robots in real-world environments like retail, manufacturing, or healthcare where hands-free interaction is more effective.

# %% [markdown]
# ## Code to convert skeleton files to numpy arrays:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile
import gdown

# Setup
file_id = '1gBjOq3tdmm8GITCf0iLX6XBjEdSPMj5Q'
zip_filename = 'DL_Data_Conversion_Chi.zip'
extract_dir = 'skeleton_dataset'        # folder to extract to

# Download if not already present
if not os.path.exists(zip_filename):
    url = f'https://drive.google.com/uc?id={file_id}'
    gdown.download(url, zip_filename, quiet=False)

# Unzip if not already extracted
if not os.path.exists(extract_dir):
    with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

print(f"✅ Dataset ready at: {extract_dir}/")
# Out:
# ✅ Dataset ready at: skeleton_dataset/

# %%
from pathlib import Path
import numpy as np
import json
from collections import defaultdict

def parse_skeleton_file_to_dict(file_path, max_body=4, njoints=25):
    with open(file_path, 'r') as f:
        datas = f.readlines()

    nframe = int(datas[0])
    if nframe == 0:
        return None

    bodymat = {
        'file_name': file_path.stem,
        'nbodys': [],
        'njoints': njoints
    }

    for body in range(max_body):
        bodymat[f'skel_body{body}'] = np.zeros((nframe, njoints, 3))
        bodymat[f'depth_body{body}'] = np.zeros((nframe, njoints, 2))
        bodymat[f'rgb_body{body}'] = np.zeros((nframe, njoints, 2))

    cursor = 0
    for frame in range(nframe):
        cursor += 1
        if cursor >= len(datas): break

        bodycount = int(datas[cursor])
        if bodycount == 0:
            continue

        bodymat['nbodys'].append(bodycount)

        for body in range(bodycount):
            cursor += 2  # skip 2 lines (body ID and metadata)
            if cursor >= len(datas): break

            joint_count = int(datas[cursor])
            for joint in range(joint_count):
                cursor += 1
                if cursor >= len(datas): break

                jointinfo = list(map(float, datas[cursor].split()))
                if joint < njoints:
                    bodymat[f'skel_body{body}'][frame, joint] = jointinfo[0:3]
                    bodymat[f'depth_body{body}'][frame, joint] = jointinfo[3:5]
                    bodymat[f'rgb_body{body}'][frame, joint] = jointinfo[5:7]

    # Remove unused bodies
    for body in range(max_body):
        if body >= max(bodymat['nbodys'], default=0):
            bodymat.pop(f'skel_body{body}', None)
            bodymat.pop(f'depth_body{body}', None)
            bodymat.pop(f'rgb_body{body}', None)

    return bodymat

def convert_skeletons_and_create_metadata(input_folder, output_folder, metadata_path=None, missing_file_list=None, max_files=None):
    input_path = Path(input_folder)
    output_path = Path(output_folder)
    output_path.mkdir(parents=True, exist_ok=True)

    if missing_file_list:
        with open(missing_file_list, 'r') as f:
            missing = {line.strip() for line in f}
    else:
        missing = set()

    metadata = {}
    class_counts = defaultdict(int)
    file_count = 0

    for file_path in sorted(input_path.rglob("*.skeleton")):
        file = file_path.name
        file_id = file[:20]
        if file_id in missing:
            print(f"❌ Skipping missing: {file}")
            continue

        if max_files is not None and file_count >= max_files:
            break

        out_file = f"{file}.npy"
        save_path = output_path / out_file

        # ✅ Always overwrite
        if save_path.exists():
            os.remove(save_path)

        data = parse_skeleton_file_to_dict(file_path)
        if data is None or 'skel_body0' not in data:
            print(f"⚠️ Skipping {file}: missing or invalid skeleton data")
            continue

        try:
            label = int(file.split('A')[1][:3]) - 1
            data['label'] = label
            np.save(save_path, data)
            metadata[out_file] = label
            class_counts[label] += 1
        except Exception as e:
            print(f"❗ Could not parse label for {file}: {e}")
            continue

        file_count += 1

    if metadata_path:
        with open(metadata_path, 'w') as f:
            json.dump(metadata, f, indent=2)
        print(f"📄 Metadata saved to: {metadata_path}")

    print(f"\n✅ Done: {file_count} files processed.")
    print("\n📊 Final class distribution:")
    for cls, count in sorted(class_counts.items()):
        print(f"  Class {cls:2d}: {count} samples")

    return metadata if metadata_path else None

# %%
for root, dirs, files in os.walk(".", topdown=True):
    for name in files:
        if name.endswith(".skeleton"):
            print(os.path.join(root, name))
            break
# Out:
# ./skeleton_dataset/DL_Data_Conversion_Chi/data/S005C003P017R002A006.skeleton

# %%
convert_skeletons_and_create_metadata(
    input_folder='skeleton_dataset',
    output_folder='/content/skeleton_dataset/converted',
    metadata_path='/content/skeleton_dataset/metadata.json',
    max_files=None
)
# Out:
# ⚠️ Skipping S001C002P006R001A008.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S001C003P005R002A004.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S001C003P005R002A005.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S001C003P005R002A006.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S002C002P011R002A030.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S002C003P011R002A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S003C003P018R002A024.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S004C002P003R001A013.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S004C002P008R001A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S004C002P020R001A003.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S004C002P020R001A004.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S004C002P020R001A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S004C002P020R001A020.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S004C002P020R001A036.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P010R001A016.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P010R001A017.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P010R001A048.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P010R001A049.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P016R001A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P016R001A010.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P018R001A003.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P018R001A028.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C002P018R001A029.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C003P016R002A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S005C003P018R002A013.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P007R001A005.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P007R001A006.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P016R001A043.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P016R001A051.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P016R001A052.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P022R001A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P023R001A020.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P023R001A021.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P023R001A022.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P023R001A023.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P024R001A018.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C002P024R001A019.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C003P001R002A013.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C003P007R002A010.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C003P007R002A025.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C003P017R002A013.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C003P017R002A014.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C003P017R002A015.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S006C003P022R002A013.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C001P028R001A050.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C001P028R001A051.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C001P028R001A052.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C002P026R001A008.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C002P026R001A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C002P026R001A010.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C002P026R001A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C002P026R001A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C002P026R001A050.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C002P027R001A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C002P027R001A013.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P007R001A002.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P007R001A004.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A001.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A002.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A003.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A004.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A005.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A006.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A007.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A008.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A010.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S007C003P027R002A013.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P001R001A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P001R001A010.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P001R001A014.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P001R001A015.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P001R001A016.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P001R001A018.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P001R001A019.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P025R001A060.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P029R001A004.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P031R001A005.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P031R001A006.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P034R001A018.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C002P034R001A019.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A016.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A017.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A018.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A019.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A020.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A021.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A022.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A023.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A025.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A028.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R001A029.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P007R002A003.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A002.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A016.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A020.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A022.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A023.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A030.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A031.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A032.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P025R002A049.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P031R001A001.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P031R002A004.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P031R002A014.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P031R002A015.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P031R002A016.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P031R002A017.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P032R002A013.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P033R002A001.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P033R002A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P033R002A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P034R002A001.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P034R002A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P034R002A022.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P034R002A023.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P034R002A044.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P034R002A045.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P035R002A016.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P035R002A017.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P035R002A018.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P035R002A019.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P035R002A020.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S008C003P035R002A021.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S009C002P007R001A001.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S009C002P007R001A003.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S009C002P016R001A002.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S009C002P017R001A028.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S009C002P017R001A029.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S009C003P017R002A030.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S010C002P017R001A005.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S010C002P017R001A018.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S010C002P017R001A019.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S010C002P019R001A001.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S010C002P025R001A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S010C003P008R002A003.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S011C002P017R001A020.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S011C002P017R001A021.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S011C002P027R001A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S011C002P027R001A010.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S011C002P027R001A037.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S011C003P008R002A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S012C003P019R002A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S012C003P019R002A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S012C003P027R002A009.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S013C003P025R002A022.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S014C002P015R001A003.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S014C002P019R001A029.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S015C002P007R001A059.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S015C002P008R001A003.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S015C002P008R001A004.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S015C002P015R001A002.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S015C002P016R001A001.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S015C003P008R002A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S015C003P008R002A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S016C001P025R001A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S016C001P025R001A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S016C002P008R001A011.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S016C002P025R002A012.skeleton: missing or invalid skeleton data
# ⚠️ Skipping S017C002P008R001A009.skeleton: missing or invalid skeleton data
# 📄 Metadata saved to: /content/skeleton_dataset/metadata.json
#
# ✅ Done: 56715 files processed.
#
# 📊 Final class distribution:
#   Class  0: 941 samples
#   Class  1: 943 samples
#   Class  2: 940 samples
#   Class  3: 941 samples
#   Class  4: 943 samples
#   Class  5: 944 samples
#   Class  6: 947 samples
#   Class  7: 945 samples
#   Class  8: 938 samples
#   Class  9: 942 samples
#   Class 10: 938 samples
#   Class 11: 935 samples
#   Class 12: 940 samples
#   Class 13: 945 samples
#   Class 14: 945 samples
#   Class 15: 942 samples
#   Class 16: 944 samples
#   Class 17: 942 samples
#   Class 18: 942 samples
#   Class 19: 942 samples
#   Class 20: 944 samples
#   Class 21: 943 samples
#   Class 22: 944 samples
#   Class 23: 947 samples
#   Class 24: 946 samples
#   Class 25: 948 samples
#   Class 26: 948 samples
#   Class 27: 945 samples
#   Class 28: 944 samples
#   Class 29: 945 samples
#   Class 30: 947 samples
#   Class 31: 947 samples
#   Class 32: 948 samples
#   Class 33: 948 samples
#   Class 34: 948 samples
#   Class 35: 947 samples
#   Class 36: 947 samples
#   Class 37: 948 samples
#   Class 38: 948 samples
#   Class 39: 948 samples
#   Class 40: 948 samples
#   Class 41: 948 samples
#   Class 42: 947 samples
#   Class 43: 947 samples
#   Class 44: 947 samples
#   Class 45: 948 samples
#   Class 46: 948 samples
#   Class 47: 947 samples
#   Class 48: 946 samples
#   Class 49: 946 samples
#   Class 50: 946 samples
#   Class 51: 946 samples
#   Class 52: 948 samples
#   Class 53: 948 samples
#   Class 54: 948 samples
#   Class 55: 948 samples
#   Class 56: 948 samples
#   Class 57: 948 samples
#   Class 58: 947 samples
#   Class 59: 947 samples
# {'S001C001P001R001A001.skeleton.npy': 0,
#  'S001C001P001R001A002.skeleton.npy': 1,
#  'S001C001P001R001A003.skeleton.npy': 2,
#  'S001C001P001R001A004.skeleton.npy': 3,
#  'S001C001P001R001A005.skeleton.npy': 4,
#  'S001C001P001R001A006.skeleton.npy': 5,
#  'S001C001P001R001A007.skeleton.npy': 6,
#  'S001C001P001R001A008.skeleton.npy': 7,
#  'S001C001P001R001A009.skeleton.npy': 8,
#  'S001C001P001R001A010.skeleton.npy': 9,
#  'S001C001P001R001A011.skeleton.npy': 10,
#  'S001C001P001R001A012.skeleton.npy': 11,
#  'S001C001P001R001A013.skeleton.npy': 12,
#  'S001C001P001R001A014.skeleton.npy': 13,
#  'S001C001P001R001A015.skeleton.npy': 14,
#  'S001C001P001R001A016.skeleton.npy': 15,
#  'S001C001P001R001A017.skeleton.npy': 16,
#  'S001C001P001R001A018.skeleton.npy': 17,
#  'S001C001P001R001A019.skeleton.npy': 18,
#  'S001C001P001R001A020.skeleton.npy': 19,
#  'S001C001P001R001A021.skeleton.npy': 20,
#  'S001C001P001R001A022.skeleton.npy': 21,
#  'S001C001P001R001A023.skeleton.npy': 22,
#  'S001C001P001R001A024.skeleton.npy': 23,
#  'S001C001P001R001A025.skeleton.npy': 24,
#  'S001C001P001R001A026.skeleton.npy': 25,
#  'S001C001P001R001A027.skeleton.npy': 26,
#  'S001C001P001R001A028.skeleton.npy': 27,
#  'S001C001P001R001A029.skeleton.npy': 28,
#  'S001C001P001R001A030.skeleton.npy': 29,
#  'S001C001P001R001A031.skeleton.npy': 30,
#  'S001C001P001R001A032.skeleton.npy': 31,
#  'S001C001P001R001A033.skeleton.npy': 32,
#  'S001C001P001R001A034.skeleton.npy': 33,
#  'S001C001P001R001A035.skeleton.npy': 34,
#  'S001C001P001R001A036.skeleton.npy': 35,
#  'S001C001P001R001A037.skeleton.npy': 36,
#  'S001C001P001R001A038.skeleton.npy': 37,
#  'S001C001P001R001A039.skeleton.npy': 38,
#  'S001C001P001R001A040.skeleton.npy': 39,
#  'S001C001P001R001A041.skeleton.npy': 40,
#  'S001C001P001R001A042.skeleton.npy': 41,
#  'S001C001P001R001A043.skeleton.npy': 42,
#  'S001C001P001R001A044.skeleton.npy': 43,
#  'S001C001P001R001A045.skeleton.npy': 44,
#  'S001C001P001R001A046.skeleton.npy': 45,
#  'S001C001P001R001A047.skeleton.npy': 46,
#  'S001C001P001R001A048.skeleton.npy': 47,
#  'S001C001P001R001A049.skeleton.npy': 48,
#  'S001C001P001R001A050.skeleton.npy': 49,
#  'S001C001P001R001A051.skeleton.npy': 50,
#  'S001C001P001R001A052.skeleton.npy': 51,
#  'S001C001P001R001A053.skeleton.npy': 52,
#  'S001C001P001R001A054.skeleton.npy': 53,
#  'S001C001P001R001A055.skeleton.npy': 54,
#  'S001C001P001R001A056.skeleton.npy': 55,
#  'S001C001P001R001A057.skeleton.npy': 56,
#  'S001C001P001R001A058.skeleton.npy': 57,
#  'S001C001P001R001A059.skeleton.npy': 58,
#  'S001C001P001R001A060.skeleton.npy': 59,
#  'S001C001P001R002A001.skeleton.npy': 0,
#  'S001C001P001R002A002.skeleton.npy': 1,
#  'S001C001P001R002A003.skeleton.npy': 2,
#  'S001C001P001R002A004.skeleton.npy': 3,
#  'S001C001P001R002A005.skeleton.npy': 4,
#  'S001C001P001R002A006.skeleton.npy': 5,
#  'S001C001P001R002A007.skeleton.npy': 6,
#  'S001C001P001R002A008.skeleton.npy': 7,
#  'S001C001P001R002A009.skeleton.npy': 8,
#  'S001C001P001R002A010.skeleton.npy': 9,
#  'S001C001P001R002A011.skeleton.npy': 10,
#  'S001C001P001R002A012.skeleton.npy': 11,
#  'S001C001P001R002A013.skeleton.npy': 12,
#  'S001C001P001R002A014.skeleton.npy': 13,
#  'S001C001P001R002A015.skeleton.npy': 14,
#  'S001C001P001R002A016.skeleton.npy': 15,
#  'S001C001P001R002A017.skeleton.npy': 16,
#  'S001C001P001R002A018.skeleton.npy': 17,
#  'S001C001P001R002A019.skeleton.npy': 18,
#  'S001C001P001R002A020.skeleton.npy': 19,
#  'S001C001P001R002A021.skeleton.npy': 20,
#  'S001C001P001R002A022.skeleton.npy': 21,
#  'S001C001P001R002A023.skeleton.npy': 22,
#  'S001C001P001R002A024.skeleton.npy': 23,
#  'S001C001P001R002A025.skeleton.npy': 24,
#  'S001C001P001R002A026.skeleton.npy': 25,
#  'S001C001P001R002A027.skeleton.npy': 26,
#  'S001C001P001R002A028.skeleton.npy': 27,
#  'S001C001P001R002A029.skeleton.npy': 28,
#  'S001C001P001R002A030.skeleton.npy': 29,
#  'S001C001P001R002A031.skeleton.npy': 30,
#  'S001C001P001R002A032.skeleton.npy': 31,
#  'S001C001P001R002A033.skeleton.npy': 32,
#  'S001C001P001R002A034.skeleton.npy': 33,
#  'S001C001P001R002A035.skeleton.npy': 34,
#  'S001C001P001R002A036.skeleton.npy': 35,
#  'S001C001P001R002A037.skeleton.npy': 36,
#  'S001C001P001R002A038.skeleton.npy': 37,
#  'S001C001P001R002A039.skeleton.npy': 38,
#  'S001C001P001R002A040.skeleton.npy': 39,
#  'S001C001P001R002A041.skeleton.npy': 40,
#  'S001C001P001R002A042.skeleton.npy': 41,
#  'S001C001P001R002A043.skeleton.npy': 42,
#  'S001C001P001R002A044.skeleton.npy': 43,
#  'S001C001P001R002A045.skeleton.npy': 44,
#  'S001C001P001R002A046.skeleton.npy': 45,
#  'S001C001P001R002A047.skeleton.npy': 46,
#  'S001C001P001R002A048.skeleton.npy': 47,
#  'S001C001P001R002A049.skeleton.npy': 48,
#  'S001C001P001R002A050.skeleton.npy': 49,
#  'S001C001P001R002A051.skeleton.npy': 50,
#  'S001C001P001R002A052.skeleton.npy': 51,
#  'S001C001P001R002A053.skeleton.npy': 52,
#  'S001C001P001R002A054.skeleton.npy': 53,
#  'S001C001P001R002A055.skeleton.npy': 54,
#  'S001C001P001R002A056.skeleton.npy': 55,
#  'S001C001P001R002A057.skeleton.npy': 56,
#  'S001C001P001R002A058.skeleton.npy': 57,
#  'S001C001P001R002A059.skeleton.npy': 58,
#  'S001C001P001R002A060.skeleton.npy': 59,
#  'S001C001P002R001A001.skeleton.npy': 0,
#  'S001C001P002R001A002.skeleton.npy': 1,
#  'S001C001P002R001A003.skeleton.npy': 2,
#  'S001C001P002R001A004.skeleton.npy': 3,
#  'S001C001P002R001A005.skeleton.npy': 4,
#  'S001C001P002R001A006.skeleton.npy': 5,
#  'S001C001P002R001A007.skeleton.npy': 6,
#  'S001C001P002R001A008.skeleton.npy': 7,
#  'S001C001P002R001A009.skeleton.npy': 8,
#  'S001C001P002R001A010.skeleton.npy': 9,
#  'S001C001P002R001A011.skeleton.npy': 10,
#  'S001C001P002R001A012.skeleton.npy': 11,
#  'S001C001P002R001A013.skeleton.npy': 12,
#  'S001C001P002R001A014.skeleton.npy': 13,
#  'S001C001P002R001A015.skeleton.npy': 14,
#  'S001C001P002R001A016.skeleton.npy': 15,
#  'S001C001P002R001A017.skeleton.npy': 16,
#  'S001C001P002R001A018.skeleton.npy': 17,
#  'S001C001P002R001A019.skeleton.npy': 18,
#  'S001C001P002R001A020.skeleton.npy': 19,
#  'S001C001P002R001A021.skeleton.npy': 20,
#  'S001C001P002R001A022.skeleton.npy': 21,
#  'S001C001P002R001A023.skeleton.npy': 22,
#  'S001C001P002R001A024.skeleton.npy': 23,
#  'S001C001P002R001A025.skeleton.npy': 24,
#  'S001C001P002R001A026.skeleton.npy': 25,
#  'S001C001P002R001A027.skeleton.npy': 26,
#  'S001C001P002R001A028.skeleton.npy': 27,
#  'S001C001P002R001A029.skeleton.npy': 28,
#  'S001C001P002R001A030.skeleton.npy': 29,
#  'S001C001P002R001A031.skeleton.npy': 30,
#  'S001C001P002R001A032.skeleton.npy': 31,
#  'S001C001P002R001A033.skeleton.npy': 32,
#  'S001C001P002R001A034.skeleton.npy': 33,
#  'S001C001P002R001A035.skeleton.npy': 34,
#  'S001C001P002R001A036.skeleton.npy': 35,
#  'S001C001P002R001A037.skeleton.npy': 36,
#  'S001C001P002R001A038.skeleton.npy': 37,
#  'S001C001P002R001A039.skeleton.npy': 38,
#  'S001C001P002R001A040.skeleton.npy': 39,
#  'S001C001P002R001A041.skeleton.npy': 40,
#  'S001C001P002R001A042.skeleton.npy': 41,
#  'S001C001P002R001A043.skeleton.npy': 42,
#  'S001C001P002R001A044.skeleton.npy': 43,
#  'S001C001P002R001A045.skeleton.npy': 44,
#  'S001C001P002R001A046.skeleton.npy': 45,
#  'S001C001P002R001A047.skeleton.npy': 46,
#  'S001C001P002R001A048.skeleton.npy': 47,
#  'S001C001P002R001A049.skeleton.npy': 48,
#  'S001C001P002R001A050.skeleton.npy': 49,
#  'S001C001P002R001A051.skeleton.npy': 50,
#  'S001C001P002R001A052.skeleton.npy': 51,
#  'S001C001P002R001A053.skeleton.npy': 52,
#  'S001C001P002R001A054.skeleton.npy': 53,
#  'S001C001P002R001A055.skeleton.npy': 54,
#  'S001C001P002R001A056.skeleton.npy': 55,
#  'S001C001P002R001A057.skeleton.npy': 56,
#  'S001C001P002R001A058.skeleton.npy': 57,
#  'S001C001P002R001A059.skeleton.npy': 58,
#  'S001C001P002R001A060.skeleton.npy': 59,
#  'S001C001P002R002A001.skeleton.npy': 0,
#  'S001C001P002R002A002.skeleton.npy': 1,
#  'S001C001P002R002A003.skeleton.npy': 2,
#  'S001C001P002R002A004.skeleton.npy': 3,
#  'S001C001P002R002A005.skeleton.npy': 4,
#  'S001C001P002R002A006.skeleton.npy': 5,
#  'S001C001P002R002A007.skeleton.npy': 6,
#  'S001C001P002R002A008.skeleton.npy': 7,
#  'S001C001P002R002A009.skeleton.npy': 8,
#  'S001C001P002R002A010.skeleton.npy': 9,
#  'S001C001P002R002A011.skeleton.npy': 10,
#  'S001C001P002R002A012.skeleton.npy': 11,
#  'S001C001P002R002A013.skeleton.npy': 12,
#  'S001C001P002R002A014.skeleton.npy': 13,
#  'S001C001P002R002A015.skeleton.npy': 14,
#  'S001C001P002R002A016.skeleton.npy': 15,
#  'S001C001P002R002A017.skeleton.npy': 16,
#  'S001C001P002R002A018.skeleton.npy': 17,
#  'S001C001P002R002A019.skeleton.npy': 18,
#  'S001C001P002R002A020.skeleton.npy': 19,
#  'S001C001P002R002A021.skeleton.npy': 20,
#  'S001C001P002R002A022.skeleton.npy': 21,
#  'S001C001P002R002A023.skeleton.npy': 22,
#  'S001C001P002R002A024.skeleton.npy': 23,
#  'S001C001P002R002A025.skeleton.npy': 24,
#  'S001C001P002R002A026.skeleton.npy': 25,
#  'S001C001P002R002A027.skeleton.npy': 26,
#  'S001C001P002R002A028.skeleton.npy': 27,
#  'S001C001P002R002A029.skeleton.npy': 28,
#  'S001C001P002R002A030.skeleton.npy': 29,
#  'S001C001P002R002A031.skeleton.npy': 30,
#  'S001C001P002R002A032.skeleton.npy': 31,
#  'S001C001P002R002A033.skeleton.npy': 32,
#  'S001C001P002R002A034.skeleton.npy': 33,
#  'S001C001P002R002A035.skeleton.npy': 34,
#  'S001C001P002R002A036.skeleton.npy': 35,
#  'S001C001P002R002A037.skeleton.npy': 36,
#  'S001C001P002R002A038.skeleton.npy': 37,
#  'S001C001P002R002A039.skeleton.npy': 38,
#  'S001C001P002R002A040.skeleton.npy': 39,
#  'S001C001P002R002A041.skeleton.npy': 40,
#  'S001C001P002R002A042.skeleton.npy': 41,
#  'S001C001P002R002A043.skeleton.npy': 42,
#  'S001C001P002R002A044.skeleton.npy': 43,
#  'S001C001P002R002A045.skeleton.npy': 44,
#  'S001C001P002R002A046.skeleton.npy': 45,
#  'S001C001P002R002A047.skeleton.npy': 46,
#  'S001C001P002R002A048.skeleton.npy': 47,
#  'S001C001P002R002A049.skeleton.npy': 48,
#  'S001C001P002R002A050.skeleton.npy': 49,
#  'S001C001P002R002A051.skeleton.npy': 50,
#  'S001C001P002R002A052.skeleton.npy': 51,
#  'S001C001P002R002A053.skeleton.npy': 52,
#  'S001C001P002R002A054.skeleton.npy': 53,
#  'S001C001P002R002A055.skeleton.npy': 54,
#  'S001C001P002R002A056.skeleton.npy': 55,
#  'S001C001P002R002A057.skeleton.npy': 56,
#  'S001C001P002R002A058.skeleton.npy': 57,
#  'S001C001P002R002A059.skeleton.npy': 58,
#  'S001C001P002R002A060.skeleton.npy': 59,
#  'S001C001P003R001A001.skeleton.npy': 0,
#  'S001C001P003R001A002.skeleton.npy': 1,
#  'S001C001P003R001A003.skeleton.npy': 2,
#  'S001C001P003R001A004.skeleton.npy': 3,
#  'S001C001P003R001A005.skeleton.npy': 4,
#  'S001C001P003R001A006.skeleton.npy': 5,
#  'S001C001P003R001A007.skeleton.npy': 6,
#  'S001C001P003R001A008.skeleton.npy': 7,
#  'S001C001P003R001A009.skeleton.npy': 8,
#  'S001C001P003R001A010.skeleton.npy': 9,
#  'S001C001P003R001A011.skeleton.npy': 10,
#  'S001C001P003R001A012.skeleton.npy': 11,
#  'S001C001P003R001A013.skeleton.npy': 12,
#  'S001C001P003R001A014.skeleton.npy': 13,
#  'S001C001P003R001A015.skeleton.npy': 14,
#  'S001C001P003R001A016.skeleton.npy': 15,
#  'S001C001P003R001A017.skeleton.npy': 16,
#  'S001C001P003R001A018.skeleton.npy': 17,
#  'S001C001P003R001A019.skeleton.npy': 18,
#  'S001C001P003R001A020.skeleton.npy': 19,
#  'S001C001P003R001A021.skeleton.npy': 20,
#  'S001C001P003R001A022.skeleton.npy': 21,
#  'S001C001P003R001A023.skeleton.npy': 22,
#  'S001C001P003R001A024.skeleton.npy': 23,
#  'S001C001P003R001A025.skeleton.npy': 24,
#  'S001C001P003R001A026.skeleton.npy': 25,
#  'S001C001P003R001A027.skeleton.npy': 26,
#  'S001C001P003R001A028.skeleton.npy': 27,
#  'S001C001P003R001A029.skeleton.npy': 28,
#  'S001C001P003R001A030.skeleton.npy': 29,
#  'S001C001P003R001A031.skeleton.npy': 30,
#  'S001C001P003R001A032.skeleton.npy': 31,
#  'S001C001P003R001A033.skeleton.npy': 32,
#  'S001C001P003R001A034.skeleton.npy': 33,
#  'S001C001P003R001A035.skeleton.npy': 34,
#  'S001C001P003R001A036.skeleton.npy': 35,
#  'S001C001P003R001A037.skeleton.npy': 36,
#  'S001C001P003R001A038.skeleton.npy': 37,
#  'S001C001P003R001A039.skeleton.npy': 38,
#  'S001C001P003R001A040.skeleton.npy': 39,
#  'S001C001P003R001A041.skeleton.npy': 40,
#  'S001C001P003R001A042.skeleton.npy': 41,
#  'S001C001P003R001A043.skeleton.npy': 42,
#  'S001C001P003R001A044.skeleton.npy': 43,
#  'S001C001P003R001A045.skeleton.npy': 44,
#  'S001C001P003R001A046.skeleton.npy': 45,
#  'S001C001P003R001A047.skeleton.npy': 46,
#  'S001C001P003R001A048.skeleton.npy': 47,
#  'S001C001P003R001A049.skeleton.npy': 48,
#  'S001C001P003R001A050.skeleton.npy': 49,
#  'S001C001P003R001A051.skeleton.npy': 50,
#  'S001C001P003R001A052.skeleton.npy': 51,
#  'S001C001P003R001A053.skeleton.npy': 52,
#  'S001C001P003R001A054.skeleton.npy': 53,
#  'S001C001P003R001A055.skeleton.npy': 54,
#  'S001C001P003R001A056.skeleton.npy': 55,
#  'S001C001P003R001A057.skeleton.npy': 56,
#  'S001C001P003R001A058.skeleton.npy': 57,
#  'S001C001P003R001A059.skeleton.npy': 58,
#  'S001C001P003R001A060.skeleton.npy': 59,
#  'S001C001P003R002A001.skeleton.npy': 0,
#  'S001C001P003R002A002.skeleton.npy': 1,
#  'S001C001P003R002A003.skeleton.npy': 2,
#  'S001C001P003R002A004.skeleton.npy': 3,
#  'S001C001P003R002A005.skeleton.npy': 4,
#  'S001C001P003R002A006.skeleton.npy': 5,
#  'S001C001P003R002A007.skeleton.npy': 6,
#  'S001C001P003R002A008.skeleton.npy': 7,
#  'S001C001P003R002A009.skeleton.npy': 8,
#  'S001C001P003R002A010.skeleton.npy': 9,
#  'S001C001P003R002A011.skeleton.npy': 10,
#  'S001C001P003R002A012.skeleton.npy': 11,
#  'S001C001P003R002A013.skeleton.npy': 12,
#  'S001C001P003R002A014.skeleton.npy': 13,
#  'S001C001P003R002A015.skeleton.npy': 14,
#  'S001C001P003R002A016.skeleton.npy': 15,
#  'S001C001P003R002A017.skeleton.npy': 16,
#  'S001C001P003R002A018.skeleton.npy': 17,
#  'S001C001P003R002A019.skeleton.npy': 18,
#  'S001C001P003R002A020.skeleton.npy': 19,
#  'S001C001P003R002A021.skeleton.npy': 20,
#  'S001C001P003R002A022.skeleton.npy': 21,
#  'S001C001P003R002A023.skeleton.npy': 22,
#  'S001C001P003R002A024.skeleton.npy': 23,
#  'S001C001P003R002A025.skeleton.npy': 24,
#  'S001C001P003R002A026.skeleton.npy': 25,
#  'S001C001P003R002A027.skeleton.npy': 26,
#  'S001C001P003R002A028.skeleton.npy': 27,
#  'S001C001P003R002A029.skeleton.npy': 28,
#  'S001C001P003R002A030.skeleton.npy': 29,
#  'S001C001P003R002A031.skeleton.npy': 30,
#  'S001C001P003R002A032.skeleton.npy': 31,
#  'S001C001P003R002A033.skeleton.npy': 32,
#  'S001C001P003R002A034.skeleton.npy': 33,
#  'S001C001P003R002A035.skeleton.npy': 34,
#  'S001C001P003R002A036.skeleton.npy': 35,
#  'S001C001P003R002A037.skeleton.npy': 36,
#  'S001C001P003R002A038.skeleton.npy': 37,
#  'S001C001P003R002A039.skeleton.npy': 38,
#  'S001C001P003R002A040.skeleton.npy': 39,
#  'S001C001P003R002A041.skeleton.npy': 40,
#  'S001C001P003R002A042.skeleton.npy': 41,
#  'S001C001P003R002A043.skeleton.npy': 42,
#  'S001C001P003R002A044.skeleton.npy': 43,
#  'S001C001P003R002A045.skeleton.npy': 44,
#  'S001C001P003R002A046.skeleton.npy': 45,
#  'S001C001P003R002A047.skeleton.npy': 46,
#  'S001C001P003R002A048.skeleton.npy': 47,
#  'S001C001P003R002A049.skeleton.npy': 48,
#  'S001C001P003R002A050.skeleton.npy': 49,
#  'S001C001P003R002A051.skeleton.npy': 50,
#  'S001C001P003R002A052.skeleton.npy': 51,
#  'S001C001P003R002A053.skeleton.npy': 52,
#  'S001C001P003R002A054.skeleton.npy': 53,
#  'S001C001P003R002A055.skeleton.npy': 54,
#  'S001C001P003R002A056.skeleton.npy': 55,
#  'S001C001P003R002A057.skeleton.npy': 56,
#  'S001C001P003R002A058.skeleton.npy': 57,
#  'S001C001P003R002A059.skeleton.npy': 58,
#  'S001C001P003R002A060.skeleton.npy': 59,
#  'S001C001P004R001A001.skeleton.npy': 0,
#  'S001C001P004R001A002.skeleton.npy': 1,
#  'S001C001P004R001A003.skeleton.npy': 2,
#  'S001C001P004R001A004.skeleton.npy': 3,
#  'S001C001P004R001A005.skeleton.npy': 4,
#  'S001C001P004R001A006.skeleton.npy': 5,
#  'S001C001P004R001A007.skeleton.npy': 6,
#  'S001C001P004R001A008.skeleton.npy': 7,
#  'S001C001P004R001A009.skeleton.npy': 8,
#  'S001C001P004R001A010.skeleton.npy': 9,
#  'S001C001P004R001A011.skeleton.npy': 10,
#  'S001C001P004R001A012.skeleton.npy': 11,
#  'S001C001P004R001A013.skeleton.npy': 12,
#  'S001C001P004R001A014.skeleton.npy': 13,
#  'S001C001P004R001A015.skeleton.npy': 14,
#  'S001C001P004R001A016.skeleton.npy': 15,
#  'S001C001P004R001A017.skeleton.npy': 16,
#  'S001C001P004R001A018.skeleton.npy': 17,
#  'S001C001P004R001A019.skeleton.npy': 18,
#  'S001C001P004R001A020.skeleton.npy': 19,
#  'S001C001P004R001A021.skeleton.npy': 20,
#  'S001C001P004R001A022.skeleton.npy': 21,
#  'S001C001P004R001A023.skeleton.npy': 22,
#  'S001C001P004R001A024.skeleton.npy': 23,
#  'S001C001P004R001A025.skeleton.npy': 24,
#  'S001C001P004R001A026.skeleton.npy': 25,
#  'S001C001P004R001A027.skeleton.npy': 26,
#  'S001C001P004R001A028.skeleton.npy': 27,
#  'S001C001P004R001A029.skeleton.npy': 28,
#  'S001C001P004R001A030.skeleton.npy': 29,
#  'S001C001P004R001A031.skeleton.npy': 30,
#  'S001C001P004R001A032.skeleton.npy': 31,
#  'S001C001P004R001A033.skeleton.npy': 32,
#  'S001C001P004R001A034.skeleton.npy': 33,
#  'S001C001P004R001A035.skeleton.npy': 34,
#  'S001C001P004R001A036.skeleton.npy': 35,
#  'S001C001P004R001A037.skeleton.npy': 36,
#  'S001C001P004R001A038.skeleton.npy': 37,
#  'S001C001P004R001A039.skeleton.npy': 38,
#  'S001C001P004R001A040.skeleton.npy': 39,
#  'S001C001P004R001A041.skeleton.npy': 40,
#  'S001C001P004R001A042.skeleton.npy': 41,
#  'S001C001P004R001A043.skeleton.npy': 42,
#  'S001C001P004R001A044.skeleton.npy': 43,
#  'S001C001P004R001A045.skeleton.npy': 44,
#  'S001C001P004R001A046.skeleton.npy': 45,
#  'S001C001P004R001A047.skeleton.npy': 46,
#  'S001C001P004R001A048.skeleton.npy': 47,
#  'S001C001P004R001A049.skeleton.npy': 48,
#  'S001C001P004R001A050.skeleton.npy': 49,
#  'S001C001P004R001A051.skeleton.npy': 50,
#  'S001C001P004R001A052.skeleton.npy': 51,
#  'S001C001P004R001A053.skeleton.npy': 52,
#  'S001C001P004R001A054.skeleton.npy': 53,
#  'S001C001P004R001A055.skeleton.npy': 54,
#  'S001C001P004R001A056.skeleton.npy': 55,
#  'S001C001P004R001A057.skeleton.npy': 56,
#  'S001C001P004R001A058.skeleton.npy': 57,
#  'S001C001P004R001A059.skeleton.npy': 58,
#  'S001C001P004R001A060.skeleton.npy': 59,
#  'S001C001P004R002A001.skeleton.npy': 0,
#  'S001C001P004R002A002.skeleton.npy': 1,
#  'S001C001P004R002A003.skeleton.npy': 2,
#  'S001C001P004R002A004.skeleton.npy': 3,
#  'S001C001P004R002A005.skeleton.npy': 4,
#  'S001C001P004R002A006.skeleton.npy': 5,
#  'S001C001P004R002A007.skeleton.npy': 6,
#  'S001C001P004R002A008.skeleton.npy': 7,
#  'S001C001P004R002A009.skeleton.npy': 8,
#  'S001C001P004R002A010.skeleton.npy': 9,
#  'S001C001P004R002A011.skeleton.npy': 10,
#  'S001C001P004R002A012.skeleton.npy': 11,
#  'S001C001P004R002A013.skeleton.npy': 12,
#  'S001C001P004R002A014.skeleton.npy': 13,
#  'S001C001P004R002A015.skeleton.npy': 14,
#  'S001C001P004R002A016.skeleton.npy': 15,
#  'S001C001P004R002A017.skeleton.npy': 16,
#  'S001C001P004R002A018.skeleton.npy': 17,
#  'S001C001P004R002A019.skeleton.npy': 18,
#  'S001C001P004R002A020.skeleton.npy': 19,
#  'S001C001P004R002A021.skeleton.npy': 20,
#  'S001C001P004R002A022.skeleton.npy': 21,
#  'S001C001P004R002A023.skeleton.npy': 22,
#  'S001C001P004R002A024.skeleton.npy': 23,
#  'S001C001P004R002A025.skeleton.npy': 24,
#  'S001C001P004R002A026.skeleton.npy': 25,
#  'S001C001P004R002A027.skeleton.npy': 26,
#  'S001C001P004R002A028.skeleton.npy': 27,
#  'S001C001P004R002A029.skeleton.npy': 28,
#  'S001C001P004R002A030.skeleton.npy': 29,
#  'S001C001P004R002A031.skeleton.npy': 30,
#  'S001C001P004R002A032.skeleton.npy': 31,
#  'S001C001P004R002A033.skeleton.npy': 32,
#  'S001C001P004R002A034.skeleton.npy': 33,
#  'S001C001P004R002A035.skeleton.npy': 34,
#  'S001C001P004R002A036.skeleton.npy': 35,
#  'S001C001P004R002A037.skeleton.npy': 36,
#  'S001C001P004R002A038.skeleton.npy': 37,
#  'S001C001P004R002A039.skeleton.npy': 38,
#  'S001C001P004R002A040.skeleton.npy': 39,
#  'S001C001P004R002A041.skeleton.npy': 40,
#  'S001C001P004R002A042.skeleton.npy': 41,
#  'S001C001P004R002A043.skeleton.npy': 42,
#  'S001C001P004R002A044.skeleton.npy': 43,
#  'S001C001P004R002A045.skeleton.npy': 44,
#  'S001C001P004R002A046.skeleton.npy': 45,
#  'S001C001P004R002A047.skeleton.npy': 46,
#  'S001C001P004R002A048.skeleton.npy': 47,
#  'S001C001P004R002A049.skeleton.npy': 48,
#  'S001C001P004R002A050.skeleton.npy': 49,
#  'S001C001P004R002A051.skeleton.npy': 50,
#  'S001C001P004R002A052.skeleton.npy': 51,
#  'S001C001P004R002A053.skeleton.npy': 52,
#  'S001C001P004R002A054.skeleton.npy': 53,
#  'S001C001P004R002A055.skeleton.npy': 54,
#  'S001C001P004R002A056.skeleton.npy': 55,
#  'S001C001P004R002A057.skeleton.npy': 56,
#  'S001C001P004R002A058.skeleton.npy': 57,
#  'S001C001P004R002A059.skeleton.npy': 58,
#  'S001C001P004R002A060.skeleton.npy': 59,
#  'S001C001P005R001A001.skeleton.npy': 0,
#  'S001C001P005R001A002.skeleton.npy': 1,
#  'S001C001P005R001A003.skeleton.npy': 2,
#  'S001C001P005R001A004.skeleton.npy': 3,
#  'S001C001P005R001A005.skeleton.npy': 4,
#  'S001C001P005R001A006.skeleton.npy': 5,
#  'S001C001P005R001A007.skeleton.npy': 6,
#  'S001C001P005R001A008.skeleton.npy': 7,
#  'S001C001P005R001A009.skeleton.npy': 8,
#  'S001C001P005R001A010.skeleton.npy': 9,
#  'S001C001P005R001A011.skeleton.npy': 10,
#  'S001C001P005R001A012.skeleton.npy': 11,
#  'S001C001P005R001A013.skeleton.npy': 12,
#  'S001C001P005R001A014.skeleton.npy': 13,
#  'S001C001P005R001A015.skeleton.npy': 14,
#  'S001C001P005R001A016.skeleton.npy': 15,
#  'S001C001P005R001A017.skeleton.npy': 16,
#  'S001C001P005R001A018.skeleton.npy': 17,
#  'S001C001P005R001A019.skeleton.npy': 18,
#  'S001C001P005R001A020.skeleton.npy': 19,
#  'S001C001P005R001A021.skeleton.npy': 20,
#  'S001C001P005R001A022.skeleton.npy': 21,
#  'S001C001P005R001A023.skeleton.npy': 22,
#  'S001C001P005R001A024.skeleton.npy': 23,
#  'S001C001P005R001A025.skeleton.npy': 24,
#  'S001C001P005R001A026.skeleton.npy': 25,
#  'S001C001P005R001A027.skeleton.npy': 26,
#  'S001C001P005R001A028.skeleton.npy': 27,
#  'S001C001P005R001A029.skeleton.npy': 28,
#  'S001C001P005R001A030.skeleton.npy': 29,
#  'S001C001P005R001A031.skeleton.npy': 30,
#  'S001C001P005R001A032.skeleton.npy': 31,
#  'S001C001P005R001A033.skeleton.npy': 32,
#  'S001C001P005R001A034.skeleton.npy': 33,
#  'S001C001P005R001A035.skeleton.npy': 34,
#  'S001C001P005R001A036.skeleton.npy': 35,
#  'S001C001P005R001A037.skeleton.npy': 36,
#  'S001C001P005R001A038.skeleton.npy': 37,
#  'S001C001P005R001A039.skeleton.npy': 38,
#  'S001C001P005R001A040.skeleton.npy': 39,
#  'S001C001P005R001A041.skeleton.npy': 40,
#  'S001C001P005R001A042.skeleton.npy': 41,
#  'S001C001P005R001A043.skeleton.npy': 42,
#  'S001C001P005R001A044.skeleton.npy': 43,
#  'S001C001P005R001A045.skeleton.npy': 44,
#  'S001C001P005R001A046.skeleton.npy': 45,
#  'S001C001P005R001A047.skeleton.npy': 46,
#  'S001C001P005R001A048.skeleton.npy': 47,
#  'S001C001P005R001A049.skeleton.npy': 48,
#  'S001C001P005R001A050.skeleton.npy': 49,
#  'S001C001P005R001A051.skeleton.npy': 50,
#  'S001C001P005R001A052.skeleton.npy': 51,
#  'S001C001P005R001A053.skeleton.npy': 52,
#  'S001C001P005R001A054.skeleton.npy': 53,
#  'S001C001P005R001A055.skeleton.npy': 54,
#  'S001C001P005R001A056.skeleton.npy': 55,
#  'S001C001P005R001A057.skeleton.npy': 56,
#  'S001C001P005R001A058.skeleton.npy': 57,
#  'S001C001P005R001A059.skeleton.npy': 58,
#  'S001C001P005R001A060.skeleton.npy': 59,
#  'S001C001P005R002A001.skeleton.npy': 0,
#  'S001C001P005R002A002.skeleton.npy': 1,
#  'S001C001P005R002A003.skeleton.npy': 2,
#  'S001C001P005R002A004.skeleton.npy': 3,
#  'S001C001P005R002A005.skeleton.npy': 4,
#  'S001C001P005R002A006.skeleton.npy': 5,
#  'S001C001P005R002A007.skeleton.npy': 6,
#  'S001C001P005R002A008.skeleton.npy': 7,
#  'S001C001P005R002A009.skeleton.npy': 8,
#  'S001C001P005R002A010.skeleton.npy': 9,
#  'S001C001P005R002A011.skeleton.npy': 10,
#  'S001C001P005R002A012.skeleton.npy': 11,
#  'S001C001P005R002A013.skeleton.npy': 12,
#  'S001C001P005R002A014.skeleton.npy': 13,
#  'S001C001P005R002A015.skeleton.npy': 14,
#  'S001C001P005R002A016.skeleton.npy': 15,
#  'S001C001P005R002A017.skeleton.npy': 16,
#  'S001C001P005R002A018.skeleton.npy': 17,
#  'S001C001P005R002A019.skeleton.npy': 18,
#  'S001C001P005R002A020.skeleton.npy': 19,
#  'S001C001P005R002A021.skeleton.npy': 20,
#  'S001C001P005R002A022.skeleton.npy': 21,
#  'S001C001P005R002A023.skeleton.npy': 22,
#  'S001C001P005R002A024.skeleton.npy': 23,
#  'S001C001P005R002A025.skeleton.npy': 24,
#  'S001C001P005R002A026.skeleton.npy': 25,
#  'S001C001P005R002A027.skeleton.npy': 26,
#  'S001C001P005R002A028.skeleton.npy': 27,
#  'S001C001P005R002A029.skeleton.npy': 28,
#  'S001C001P005R002A030.skeleton.npy': 29,
#  'S001C001P005R002A031.skeleton.npy': 30,
#  'S001C001P005R002A032.skeleton.npy': 31,
#  'S001C001P005R002A033.skeleton.npy': 32,
#  'S001C001P005R002A034.skeleton.npy': 33,
#  'S001C001P005R002A035.skeleton.npy': 34,
#  'S001C001P005R002A036.skeleton.npy': 35,
#  'S001C001P005R002A037.skeleton.npy': 36,
#  'S001C001P005R002A038.skeleton.npy': 37,
#  'S001C001P005R002A039.skeleton.npy': 38,
#  'S001C001P005R002A040.skeleton.npy': 39,
#  'S001C001P005R002A041.skeleton.npy': 40,
#  'S001C001P005R002A042.skeleton.npy': 41,
#  'S001C001P005R002A043.skeleton.npy': 42,
#  'S001C001P005R002A044.skeleton.npy': 43,
#  'S001C001P005R002A045.skeleton.npy': 44,
#  'S001C001P005R002A046.skeleton.npy': 45,
#  'S001C001P005R002A047.skeleton.npy': 46,
#  'S001C001P005R002A048.skeleton.npy': 47,
#  'S001C001P005R002A049.skeleton.npy': 48,
#  'S001C001P005R002A050.skeleton.npy': 49,
#  'S001C001P005R002A051.skeleton.npy': 50,
#  'S001C001P005R002A052.skeleton.npy': 51,
#  'S001C001P005R002A053.skeleton.npy': 52,
#  'S001C001P005R002A054.skeleton.npy': 53,
#  'S001C001P005R002A055.skeleton.npy': 54,
#  'S001C001P005R002A056.skeleton.npy': 55,
#  'S001C001P005R002A057.skeleton.npy': 56,
#  'S001C001P005R002A058.skeleton.npy': 57,
#  'S001C001P005R002A059.skeleton.npy': 58,
#  'S001C001P005R002A060.skeleton.npy': 59,
#  'S001C001P006R001A001.skeleton.npy': 0,
#  'S001C001P006R001A002.skeleton.npy': 1,
#  'S001C001P006R001A003.skeleton.npy': 2,
#  'S001C001P006R001A004.skeleton.npy': 3,
#  'S001C001P006R001A005.skeleton.npy': 4,
#  'S001C001P006R001A006.skeleton.npy': 5,
#  'S001C001P006R001A007.skeleton.npy': 6,
#  'S001C001P006R001A008.skeleton.npy': 7,
#  'S001C001P006R001A009.skeleton.npy': 8,
#  'S001C001P006R001A010.skeleton.npy': 9,
#  'S001C001P006R001A011.skeleton.npy': 10,
#  'S001C001P006R001A012.skeleton.npy': 11,
#  'S001C001P006R001A013.skeleton.npy': 12,
#  'S001C001P006R001A014.skeleton.npy': 13,
#  'S001C001P006R001A015.skeleton.npy': 14,
#  'S001C001P006R001A016.skeleton.npy': 15,
#  'S001C001P006R001A017.skeleton.npy': 16,
#  'S001C001P006R001A018.skeleton.npy': 17,
#  'S001C001P006R001A019.skeleton.npy': 18,
#  'S001C001P006R001A020.skeleton.npy': 19,
#  'S001C001P006R001A021.skeleton.npy': 20,
#  'S001C001P006R001A022.skeleton.npy': 21,
#  'S001C001P006R001A023.skeleton.npy': 22,
#  'S001C001P006R001A024.skeleton.npy': 23,
#  'S001C001P006R001A025.skeleton.npy': 24,
#  'S001C001P006R001A026.skeleton.npy': 25,
#  'S001C001P006R001A027.skeleton.npy': 26,
#  'S001C001P006R001A028.skeleton.npy': 27,
#  'S001C001P006R001A029.skeleton.npy': 28,
#  'S001C001P006R001A030.skeleton.npy': 29,
#  'S001C001P006R001A031.skeleton.npy': 30,
#  'S001C001P006R001A032.skeleton.npy': 31,
#  'S001C001P006R001A033.skeleton.npy': 32,
#  'S001C001P006R001A034.skeleton.npy': 33,
#  'S001C001P006R001A035.skeleton.npy': 34,
#  'S001C001P006R001A036.skeleton.npy': 35,
#  'S001C001P006R001A037.skeleton.npy': 36,
#  'S001C001P006R001A038.skeleton.npy': 37,
#  'S001C001P006R001A039.skeleton.npy': 38,
#  'S001C001P006R001A040.skeleton.npy': 39,
#  'S001C001P006R001A041.skeleton.npy': 40,
#  'S001C001P006R001A042.skeleton.npy': 41,
#  'S001C001P006R001A043.skeleton.npy': 42,
#  'S001C001P006R001A044.skeleton.npy': 43,
#  'S001C001P006R001A045.skeleton.npy': 44,
#  'S001C001P006R001A046.skeleton.npy': 45,
#  'S001C001P006R001A047.skeleton.npy': 46,
#  'S001C001P006R001A048.skeleton.npy': 47,
#  'S001C001P006R001A049.skeleton.npy': 48,
#  'S001C001P006R001A050.skeleton.npy': 49,
#  'S001C001P006R001A051.skeleton.npy': 50,
#  'S001C001P006R001A052.skeleton.npy': 51,
#  'S001C001P006R001A053.skeleton.npy': 52,
#  'S001C001P006R001A054.skeleton.npy': 53,
#  'S001C001P006R001A055.skeleton.npy': 54,
#  'S001C001P006R001A056.skeleton.npy': 55,
#  'S001C001P006R001A057.skeleton.npy': 56,
#  'S001C001P006R001A058.skeleton.npy': 57,
#  'S001C001P006R001A059.skeleton.npy': 58,
#  'S001C001P006R001A060.skeleton.npy': 59,
#  'S001C001P006R002A001.skeleton.npy': 0,
#  'S001C001P006R002A002.skeleton.npy': 1,
#  'S001C001P006R002A003.skeleton.npy': 2,
#  'S001C001P006R002A004.skeleton.npy': 3,
#  'S001C001P006R002A005.skeleton.npy': 4,
#  'S001C001P006R002A006.skeleton.npy': 5,
#  'S001C001P006R002A007.skeleton.npy': 6,
#  'S001C001P006R002A008.skeleton.npy': 7,
#  'S001C001P006R002A009.skeleton.npy': 8,
#  'S001C001P006R002A010.skeleton.npy': 9,
#  'S001C001P006R002A011.skeleton.npy': 10,
#  'S001C001P006R002A012.skeleton.npy': 11,
#  'S001C001P006R002A013.skeleton.npy': 12,
#  'S001C001P006R002A014.skeleton.npy': 13,
#  'S001C001P006R002A015.skeleton.npy': 14,
#  'S001C001P006R002A016.skeleton.npy': 15,
#  'S001C001P006R002A017.skeleton.npy': 16,
#  'S001C001P006R002A018.skeleton.npy': 17,
#  'S001C001P006R002A019.skeleton.npy': 18,
#  'S001C001P006R002A020.skeleton.npy': 19,
#  'S001C001P006R002A021.skeleton.npy': 20,
#  'S001C001P006R002A022.skeleton.npy': 21,
#  'S001C001P006R002A023.skeleton.npy': 22,
#  'S001C001P006R002A024.skeleton.npy': 23,
#  'S001C001P006R002A025.skeleton.npy': 24,
#  'S001C001P006R002A026.skeleton.npy': 25,
#  'S001C001P006R002A027.skeleton.npy': 26,
#  'S001C001P006R002A028.skeleton.npy': 27,
#  'S001C001P006R002A029.skeleton.npy': 28,
#  'S001C001P006R002A030.skeleton.npy': 29,
#  'S001C001P006R002A031.skeleton.npy': 30,
#  'S001C001P006R002A032.skeleton.npy': 31,
#  'S001C001P006R002A033.skeleton.npy': 32,
#  'S001C001P006R002A034.skeleton.npy': 33,
#  'S001C001P006R002A035.skeleton.npy': 34,
#  'S001C001P006R002A036.skeleton.npy': 35,
#  'S001C001P006R002A037.skeleton.npy': 36,
#  'S001C001P006R002A038.skeleton.npy': 37,
#  'S001C001P006R002A039.skeleton.npy': 38,
#  'S001C001P006R002A040.skeleton.npy': 39,
#  'S001C001P006R002A041.skeleton.npy': 40,
#  'S001C001P006R002A042.skeleton.npy': 41,
#  'S001C001P006R002A043.skeleton.npy': 42,
#  'S001C001P006R002A044.skeleton.npy': 43,
#  'S001C001P006R002A045.skeleton.npy': 44,
#  'S001C001P006R002A046.skeleton.npy': 45,
#  'S001C001P006R002A047.skeleton.npy': 46,
#  'S001C001P006R002A048.skeleton.npy': 47,
#  'S001C001P006R002A049.skeleton.npy': 48,
#  'S001C001P006R002A050.skeleton.npy': 49,
#  'S001C001P006R002A051.skeleton.npy': 50,
#  'S001C001P006R002A052.skeleton.npy': 51,
#  'S001C001P006R002A053.skeleton.npy': 52,
#  'S001C001P006R002A054.skeleton.npy': 53,
#  'S001C001P006R002A055.skeleton.npy': 54,
#  'S001C001P006R002A056.skeleton.npy': 55,
#  'S001C001P006R002A057.skeleton.npy': 56,
#  'S001C001P006R002A058.skeleton.npy': 57,
#  'S001C001P006R002A059.skeleton.npy': 58,
#  'S001C001P006R002A060.skeleton.npy': 59,
#  'S001C001P007R001A001.skeleton.npy': 0,
#  'S001C001P007R001A002.skeleton.npy': 1,
#  'S001C001P007R001A003.skeleton.npy': 2,
#  'S001C001P007R001A004.skeleton.npy': 3,
#  'S001C001P007R001A005.skeleton.npy': 4,
#  'S001C001P007R001A006.skeleton.npy': 5,
#  'S001C001P007R001A007.skeleton.npy': 6,
#  'S001C001P007R001A008.skeleton.npy': 7,
#  'S001C001P007R001A009.skeleton.npy': 8,
#  'S001C001P007R001A010.skeleton.npy': 9,
#  'S001C001P007R001A011.skeleton.npy': 10,
#  'S001C001P007R001A012.skeleton.npy': 11,
#  'S001C001P007R001A013.skeleton.npy': 12,
#  'S001C001P007R001A014.skeleton.npy': 13,
#  'S001C001P007R001A015.skeleton.npy': 14,
#  'S001C001P007R001A016.skeleton.npy': 15,
#  'S001C001P007R001A017.skeleton.npy': 16,
#  'S001C001P007R001A018.skeleton.npy': 17,
#  'S001C001P007R001A019.skeleton.npy': 18,
#  'S001C001P007R001A020.skeleton.npy': 19,
#  'S001C001P007R001A021.skeleton.npy': 20,
#  'S001C001P007R001A022.skeleton.npy': 21,
#  'S001C001P007R001A023.skeleton.npy': 22,
#  'S001C001P007R001A024.skeleton.npy': 23,
#  'S001C001P007R001A025.skeleton.npy': 24,
#  'S001C001P007R001A026.skeleton.npy': 25,
#  'S001C001P007R001A027.skeleton.npy': 26,
#  'S001C001P007R001A028.skeleton.npy': 27,
#  'S001C001P007R001A029.skeleton.npy': 28,
#  'S001C001P007R001A030.skeleton.npy': 29,
#  'S001C001P007R001A031.skeleton.npy': 30,
#  'S001C001P007R001A032.skeleton.npy': 31,
#  'S001C001P007R001A033.skeleton.npy': 32,
#  'S001C001P007R001A034.skeleton.npy': 33,
#  'S001C001P007R001A035.skeleton.npy': 34,
#  'S001C001P007R001A036.skeleton.npy': 35,
#  'S001C001P007R001A037.skeleton.npy': 36,
#  'S001C001P007R001A038.skeleton.npy': 37,
#  'S001C001P007R001A039.skeleton.npy': 38,
#  'S001C001P007R001A040.skeleton.npy': 39,
#  'S001C001P007R001A041.skeleton.npy': 40,
#  'S001C001P007R001A042.skeleton.npy': 41,
#  'S001C001P007R001A043.skeleton.npy': 42,
#  'S001C001P007R001A044.skeleton.npy': 43,
#  'S001C001P007R001A045.skeleton.npy': 44,
#  'S001C001P007R001A046.skeleton.npy': 45,
#  'S001C001P007R001A047.skeleton.npy': 46,
#  'S001C001P007R001A048.skeleton.npy': 47,
#  'S001C001P007R001A049.skeleton.npy': 48,
#  'S001C001P007R001A050.skeleton.npy': 49,
#  'S001C001P007R001A051.skeleton.npy': 50,
#  'S001C001P007R001A052.skeleton.npy': 51,
#  'S001C001P007R001A053.skeleton.npy': 52,
#  'S001C001P007R001A054.skeleton.npy': 53,
#  'S001C001P007R001A055.skeleton.npy': 54,
#  'S001C001P007R001A056.skeleton.npy': 55,
#  'S001C001P007R001A057.skeleton.npy': 56,
#  'S001C001P007R001A058.skeleton.npy': 57,
#  'S001C001P007R001A059.skeleton.npy': 58,
#  'S001C001P007R001A060.skeleton.npy': 59,
#  'S001C001P007R002A001.skeleton.npy': 0,
#  'S001C001P007R002A002.skeleton.npy': 1,
#  'S001C001P007R002A003.skeleton.npy': 2,
#  'S001C001P007R002A004.skeleton.npy': 3,
#  'S001C001P007R002A005.skeleton.npy': 4,
#  'S001C001P007R002A006.skeleton.npy': 5,
#  'S001C001P007R002A007.skeleton.npy': 6,
#  'S001C001P007R002A008.skeleton.npy': 7,
#  'S001C001P007R002A009.skeleton.npy': 8,
#  'S001C001P007R002A010.skeleton.npy': 9,
#  'S001C001P007R002A011.skeleton.npy': 10,
#  'S001C001P007R002A012.skeleton.npy': 11,
#  'S001C001P007R002A013.skeleton.npy': 12,
#  'S001C001P007R002A014.skeleton.npy': 13,
#  'S001C001P007R002A015.skeleton.npy': 14,
#  'S001C001P007R002A016.skeleton.npy': 15,
#  'S001C001P007R002A017.skeleton.npy': 16,
#  'S001C001P007R002A018.skeleton.npy': 17,
#  'S001C001P007R002A019.skeleton.npy': 18,
#  'S001C001P007R002A020.skeleton.npy': 19,
#  'S001C001P007R002A021.skeleton.npy': 20,
#  'S001C001P007R002A022.skeleton.npy': 21,
#  'S001C001P007R002A023.skeleton.npy': 22,
#  'S001C001P007R002A024.skeleton.npy': 23,
#  'S001C001P007R002A025.skeleton.npy': 24,
#  'S001C001P007R002A026.skeleton.npy': 25,
#  'S001C001P007R002A027.skeleton.npy': 26,
#  'S001C001P007R002A028.skeleton.npy': 27,
#  'S001C001P007R002A029.skeleton.npy': 28,
#  'S001C001P007R002A030.skeleton.npy': 29,
#  'S001C001P007R002A031.skeleton.npy': 30,
#  'S001C001P007R002A032.skeleton.npy': 31,
#  'S001C001P007R002A033.skeleton.npy': 32,
#  'S001C001P007R002A034.skeleton.npy': 33,
#  'S001C001P007R002A035.skeleton.npy': 34,
#  'S001C001P007R002A036.skeleton.npy': 35,
#  'S001C001P007R002A037.skeleton.npy': 36,
#  'S001C001P007R002A038.skeleton.npy': 37,
#  'S001C001P007R002A039.skeleton.npy': 38,
#  'S001C001P007R002A040.skeleton.npy': 39,
#  'S001C001P007R002A041.skeleton.npy': 40,
#  'S001C001P007R002A042.skeleton.npy': 41,
#  'S001C001P007R002A043.skeleton.npy': 42,
#  'S001C001P007R002A044.skeleton.npy': 43,
#  'S001C001P007R002A045.skeleton.npy': 44,
#  'S001C001P007R002A046.skeleton.npy': 45,
#  'S001C001P007R002A047.skeleton.npy': 46,
#  'S001C001P007R002A048.skeleton.npy': 47,
#  'S001C001P007R002A049.skeleton.npy': 48,
#  'S001C001P007R002A050.skeleton.npy': 49,
#  'S001C001P007R002A051.skeleton.npy': 50,
#  'S001C001P007R002A052.skeleton.npy': 51,
#  'S001C001P007R002A053.skeleton.npy': 52,
#  'S001C001P007R002A054.skeleton.npy': 53,
#  'S001C001P007R002A055.skeleton.npy': 54,
#  'S001C001P007R002A056.skeleton.npy': 55,
#  'S001C001P007R002A057.skeleton.npy': 56,
#  'S001C001P007R002A058.skeleton.npy': 57,
#  'S001C001P007R002A059.skeleton.npy': 58,
#  'S001C001P007R002A060.skeleton.npy': 59,
#  'S001C001P008R001A001.skeleton.npy': 0,
#  'S001C001P008R001A002.skeleton.npy': 1,
#  'S001C001P008R001A003.skeleton.npy': 2,
#  'S001C001P008R001A004.skeleton.npy': 3,
#  'S001C001P008R001A005.skeleton.npy': 4,
#  'S001C001P008R001A006.skeleton.npy': 5,
#  'S001C001P008R001A007.skeleton.npy': 6,
#  'S001C001P008R001A008.skeleton.npy': 7,
#  'S001C001P008R001A009.skeleton.npy': 8,
#  'S001C001P008R001A010.skeleton.npy': 9,
#  'S001C001P008R001A011.skeleton.npy': 10,
#  'S001C001P008R001A012.skeleton.npy': 11,
#  'S001C001P008R001A013.skeleton.npy': 12,
#  'S001C001P008R001A014.skeleton.npy': 13,
#  'S001C001P008R001A015.skeleton.npy': 14,
#  'S001C001P008R001A016.skeleton.npy': 15,
#  'S001C001P008R001A017.skeleton.npy': 16,
#  'S001C001P008R001A018.skeleton.npy': 17,
#  'S001C001P008R001A019.skeleton.npy': 18,
#  'S001C001P008R001A020.skeleton.npy': 19,
#  'S001C001P008R001A021.skeleton.npy': 20,
#  'S001C001P008R001A022.skeleton.npy': 21,
#  'S001C001P008R001A023.skeleton.npy': 22,
#  'S001C001P008R001A024.skeleton.npy': 23,
#  'S001C001P008R001A025.skeleton.npy': 24,
#  'S001C001P008R001A026.skeleton.npy': 25,
#  'S001C001P008R001A027.skeleton.npy': 26,
#  'S001C001P008R001A028.skeleton.npy': 27,
#  'S001C001P008R001A029.skeleton.npy': 28,
#  'S001C001P008R001A030.skeleton.npy': 29,
#  'S001C001P008R001A031.skeleton.npy': 30,
#  'S001C001P008R001A032.skeleton.npy': 31,
#  'S001C001P008R001A033.skeleton.npy': 32,
#  'S001C001P008R001A034.skeleton.npy': 33,
#  'S001C001P008R001A035.skeleton.npy': 34,
#  'S001C001P008R001A036.skeleton.npy': 35,
#  'S001C001P008R001A037.skeleton.npy': 36,
#  'S001C001P008R001A038.skeleton.npy': 37,
#  'S001C001P008R001A039.skeleton.npy': 38,
#  'S001C001P008R001A040.skeleton.npy': 39,
#  'S001C001P008R001A041.skeleton.npy': 40,
#  'S001C001P008R001A042.skeleton.npy': 41,
#  'S001C001P008R001A043.skeleton.npy': 42,
#  'S001C001P008R001A044.skeleton.npy': 43,
#  'S001C001P008R001A045.skeleton.npy': 44,
#  'S001C001P008R001A046.skeleton.npy': 45,
#  'S001C001P008R001A047.skeleton.npy': 46,
#  'S001C001P008R001A048.skeleton.npy': 47,
#  'S001C001P008R001A049.skeleton.npy': 48,
#  'S001C001P008R001A050.skeleton.npy': 49,
#  'S001C001P008R001A051.skeleton.npy': 50,
#  'S001C001P008R001A052.skeleton.npy': 51,
#  'S001C001P008R001A053.skeleton.npy': 52,
#  'S001C001P008R001A054.skeleton.npy': 53,
#  'S001C001P008R001A055.skeleton.npy': 54,
#  'S001C001P008R001A056.skeleton.npy': 55,
#  'S001C001P008R001A057.skeleton.npy': 56,
#  'S001C001P008R001A058.skeleton.npy': 57,
#  'S001C001P008R001A059.skeleton.npy': 58,
#  'S001C001P008R001A060.skeleton.npy': 59,
#  'S001C001P008R002A001.skeleton.npy': 0,
#  'S001C001P008R002A002.skeleton.npy': 1,
#  'S001C001P008R002A003.skeleton.npy': 2,
#  'S001C001P008R002A004.skeleton.npy': 3,
#  'S001C001P008R002A005.skeleton.npy': 4,
#  'S001C001P008R002A006.skeleton.npy': 5,
#  'S001C001P008R002A007.skeleton.npy': 6,
#  'S001C001P008R002A008.skeleton.npy': 7,
#  'S001C001P008R002A009.skeleton.npy': 8,
#  'S001C001P008R002A010.skeleton.npy': 9,
#  'S001C001P008R002A011.skeleton.npy': 10,
#  'S001C001P008R002A012.skeleton.npy': 11,
#  'S001C001P008R002A013.skeleton.npy': 12,
#  'S001C001P008R002A014.skeleton.npy': 13,
#  'S001C001P008R002A015.skeleton.npy': 14,
#  'S001C001P008R002A016.skeleton.npy': 15,
#  'S001C001P008R002A017.skeleton.npy': 16,
#  'S001C001P008R002A018.skeleton.npy': 17,
#  'S001C001P008R002A019.skeleton.npy': 18,
#  'S001C001P008R002A020.skeleton.npy': 19,
#  'S001C001P008R002A021.skeleton.npy': 20,
#  'S001C001P008R002A022.skeleton.npy': 21,
#  'S001C001P008R002A023.skeleton.npy': 22,
#  'S001C001P008R002A024.skeleton.npy': 23,
#  'S001C001P008R002A025.skeleton.npy': 24,
#  'S001C001P008R002A026.skeleton.npy': 25,
#  'S001C001P008R002A027.skeleton.npy': 26,
#  'S001C001P008R002A028.skeleton.npy': 27,
#  'S001C001P008R002A029.skeleton.npy': 28,
#  'S001C001P008R002A030.skeleton.npy': 29,
#  'S001C001P008R002A031.skeleton.npy': 30,
#  'S001C001P008R002A032.skeleton.npy': 31,
#  'S001C001P008R002A033.skeleton.npy': 32,
#  'S001C001P008R002A034.skeleton.npy': 33,
#  'S001C001P008R002A035.skeleton.npy': 34,
#  'S001C001P008R002A036.skeleton.npy': 35,
#  'S001C001P008R002A037.skeleton.npy': 36,
#  'S001C001P008R002A038.skeleton.npy': 37,
#  'S001C001P008R002A039.skeleton.npy': 38,
#  'S001C001P008R002A040.skeleton.npy': 39,
#  'S001C001P008R002A041.skeleton.npy': 40,
#  'S001C001P008R002A042.skeleton.npy': 41,
#  'S001C001P008R002A043.skeleton.npy': 42,
#  'S001C001P008R002A044.skeleton.npy': 43,
#  'S001C001P008R002A045.skeleton.npy': 44,
#  'S001C001P008R002A046.skeleton.npy': 45,
#  'S001C001P008R002A047.skeleton.npy': 46,
#  'S001C001P008R002A048.skeleton.npy': 47,
#  'S001C001P008R002A049.skeleton.npy': 48,
#  'S001C001P008R002A050.skeleton.npy': 49,
#  'S001C001P008R002A051.skeleton.npy': 50,
#  'S001C001P008R002A052.skeleton.npy': 51,
#  'S001C001P008R002A053.skeleton.npy': 52,
#  'S001C001P008R002A054.skeleton.npy': 53,
#  'S001C001P008R002A055.skeleton.npy': 54,
#  'S001C001P008R002A056.skeleton.npy': 55,
#  'S001C001P008R002A057.skeleton.npy': 56,
#  'S001C001P008R002A058.skeleton.npy': 57,
#  'S001C001P008R002A059.skeleton.npy': 58,
#  'S001C001P008R002A060.skeleton.npy': 59,
#  'S001C002P001R001A001.skeleton.npy': 0,
#  'S001C002P001R001A002.skeleton.npy': 1,
#  'S001C002P001R001A003.skeleton.npy': 2,
#  'S001C002P001R001A004.skeleton.npy': 3,
#  'S001C002P001R001A005.skeleton.npy': 4,
#  'S001C002P001R001A006.skeleton.npy': 5,
#  'S001C002P001R001A007.skeleton.npy': 6,
#  'S001C002P001R001A008.skeleton.npy': 7,
#  'S001C002P001R001A009.skeleton.npy': 8,
#  'S001C002P001R001A010.skeleton.npy': 9,
#  'S001C002P001R001A011.skeleton.npy': 10,
#  'S001C002P001R001A012.skeleton.npy': 11,
#  'S001C002P001R001A013.skeleton.npy': 12,
#  'S001C002P001R001A014.skeleton.npy': 13,
#  'S001C002P001R001A015.skeleton.npy': 14,
#  'S001C002P001R001A016.skeleton.npy': 15,
#  'S001C002P001R001A017.skeleton.npy': 16,
#  'S001C002P001R001A018.skeleton.npy': 17,
#  'S001C002P001R001A019.skeleton.npy': 18,
#  'S001C002P001R001A020.skeleton.npy': 19,
#  'S001C002P001R001A021.skeleton.npy': 20,
#  'S001C002P001R001A022.skeleton.npy': 21,
#  'S001C002P001R001A023.skeleton.npy': 22,
#  'S001C002P001R001A024.skeleton.npy': 23,
#  'S001C002P001R001A025.skeleton.npy': 24,
#  'S001C002P001R001A026.skeleton.npy': 25,
#  'S001C002P001R001A027.skeleton.npy': 26,
#  'S001C002P001R001A028.skeleton.npy': 27,
#  'S001C002P001R001A029.skeleton.npy': 28,
#  'S001C002P001R001A030.skeleton.npy': 29,
#  'S001C002P001R001A031.skeleton.npy': 30,
#  'S001C002P001R001A032.skeleton.npy': 31,
#  'S001C002P001R001A033.skeleton.npy': 32,
#  'S001C002P001R001A034.skeleton.npy': 33,
#  'S001C002P001R001A035.skeleton.npy': 34,
#  'S001C002P001R001A036.skeleton.npy': 35,
#  'S001C002P001R001A037.skeleton.npy': 36,
#  'S001C002P001R001A038.skeleton.npy': 37,
#  'S001C002P001R001A039.skeleton.npy': 38,
#  'S001C002P001R001A040.skeleton.npy': 39,
#  ...}

# %%
import shutil
shutil.move('/content/skeleton_dataset/DL_Data_Conversion_Chi/parsed_data/metadata.json', '/skeleton_dataset/metadata.json')
# Out:
# '/skeleton_dataset/metadata.json'

# %% [markdown]
# ## Now parse all files and assign labels (based on action ID in filename):

# %%
import torch
from torch.utils.data import Dataset
from pathlib import Path

class SkeletonDatasetCTR(Dataset):
    def __init__(self, data_dir, metadata_path=None, target_frames=50):
        self.data_dir = Path(data_dir)
        self.target_frames = target_frames
        self.metadata_path = metadata_path

        if self.metadata_path:
            with open(self.metadata_path, 'r') as f:
                self.metadata = json.load(f)
            self.files = list(self.metadata.keys())
        else:
            self.metadata = None
            self.files = [f.name for f in self.data_dir.glob('*.npy')]

    def center_skeleton(self, skel):
        center = skel[:, 0:1, :]
        return skel - center

    def normalize_skeleton(self, skel):
        max_val = np.max(np.abs(skel))
        return skel / (max_val + 1e-5)

    def sample_frames(self, skel):
        n_frames = skel.shape[0]
        if n_frames == self.target_frames:
            return skel
        elif n_frames > self.target_frames:
            idx = np.linspace(0, n_frames - 1, self.target_frames).astype(int)
            return skel[idx]
        else:
            pad = np.repeat(skel[-1:], self.target_frames - n_frames, axis=0)
            return np.concatenate([skel, pad], axis=0)

    def reshape_for_ctr(self, skel):
        skel = skel.reshape(self.target_frames, 25, 3)
        return np.transpose(skel, (2, 0, 1))  # (C, T, V)

    def __len__(self):
        return len(self.files)

    def compute_bone_stream(self, skel):
     bone_pairs = [
        (1, 0), (2, 1), (3, 2), (4, 3),
        (5, 0), (6, 5), (7, 6), (8, 7),
        (9, 0), (10, 9), (11, 10), (12, 11),
        (13, 0), (14, 13), (15, 14), (16, 15),
        (17, 0), (18, 17), (19, 18), (20, 19),
        (21, 0), (22, 21), (23, 22), (24, 23)
     ]
     bone = np.zeros_like(skel)
     for j1, j2 in bone_pairs:
        bone[:, j1, :] = skel[:, j1, :] - skel[:, j2, :]
     return bone

    def __getitem__(self, idx):
      file_name = self.files[idx]
      skeleton = np.load(self.data_dir / file_name, allow_pickle=True).item()

      skel = skeleton['skel_body0']
      label = skeleton['label'] if self.metadata is None else self.metadata[file_name]

      skel = self.center_skeleton(skel)
      skel = self.normalize_skeleton(skel)
      skel = self.sample_frames(skel)

    # Augmentations
      if np.random.rand() < 0.3:
          skel += np.random.normal(0, 0.02, skel.shape)
      if np.random.rand() < 0.3:
          shuffle_idx = np.random.permutation(self.target_frames)
          skel = skel[shuffle_idx]
      if np.random.rand() < 0.2:
          skel *= (0.9 + 0.2 * np.random.rand())

      joint_stream = self.reshape_for_ctr(skel)  # (3, T, V)
      bone_stream = self.reshape_for_ctr(self.compute_bone_stream(skel))  # (3, T, V)

      return (
          torch.tensor(joint_stream, dtype=torch.float32),
          torch.tensor(bone_stream, dtype=torch.float32),
         torch.tensor(label, dtype=torch.long)
      )

# %%
skeleton_files = list(Path("skeleton_dataset").rglob("*.skeleton"))
print(f"Found {len(skeleton_files)} skeleton files")
if skeleton_files:
    print("Example file path:", skeleton_files[0])
# Out:
# Found 56880 skeleton files
# Example file path: skeleton_dataset/DL_Data_Conversion_Chi/data/S005C003P017R002A006.skeleton

# %% [markdown]
# # **TCN**

# %%
import torch.nn as nn
import torch.nn.functional as F

class TCNModel(nn.Module):
    def __init__(self, in_channels=3, num_classes=60, num_joints=25, num_frames=50):
        super(TCNModel, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, 64, kernel_size=1)
        self.bn1 = nn.BatchNorm2d(64)

        self.tcn1 = nn.Conv2d(64, 128, kernel_size=(9, 1), padding=(4, 0))
        self.bn2 = nn.BatchNorm2d(128)

        self.tcn2 = nn.Conv2d(128, 256, kernel_size=(9, 1), padding=(4, 0))
        self.bn3 = nn.BatchNorm2d(256)

        self.dropout = nn.Dropout(p=0.3)  # Dropout before flattening

        self.dropout = nn.Dropout(p=0.3)
        self.global_pool = nn.AdaptiveAvgPool2d((1, 1))  # NEW: Global Average Pooling
        self.fc = nn.Linear(256, num_classes)  # Changed from flattened 320k+ vector

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.stgcn1(x)))
        x = F.relu(self.bn3(self.stgcn2(x)))
        x = self.dropout(x)              # Apply dropout before flattening
        x = self.global_pool(x)
        x = x.view(x.size(0), -1)        # Flatten
        x = self.fc(x)
        return x

# %%
class TwoStreamTCN(nn.Module):
    def __init__(self, base_model_cls, num_classes=60):
        super().__init__()
        self.joint_model = base_model_cls(num_classes=num_classes)
        self.bone_model = base_model_cls(num_classes=num_classes)
        self.fc_fuse = nn.Linear(2 * num_classes, num_classes)

    def forward(self, joint_x, bone_x):
        joint_out = self.joint_model(joint_x)
        bone_out = self.bone_model(bone_x)
        combined = torch.cat((joint_out, bone_out), dim=1)
        return self.fc_fuse(combined)

# %%
import os

directory = '/skeleton_dataset/converted/'
file_count = len([f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))])

print(f"Number of files in '{directory}': {file_count}")
# Out:
# Number of files in '/skeleton_dataset/converted/': 56715

# %%
import os
import json

data_dir = "/skeleton_dataset/converted/"
metadata = {}

for filename in os.listdir(data_dir):
    if filename.endswith(".npy"):
        try:
            # Assume label can be parsed from filename (as in previous snippets)
            label = int(filename.split('A')[1][:3]) - 1
            metadata[filename] = label
        except Exception as e:
            print(f"Could not parse label for {filename}: {e}")
            # Decide how to handle these, maybe assign a default label or skip them

with open("/skeleton_dataset/metadata.json", "w") as f:
    json.dump(metadata, f, indent=2)

# %%
import torch
from torch.utils.data import DataLoader, random_split
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import OneCycleLR
import json

# Hyperparameters
batch_size = 64
epochs = 100
learning_rate = 0.01
val_split = 0.2
num_classes = 60

# Load dataset
full_dataset = SkeletonDatasetTCN("/skeleton_dataset/converted/", metadata_path="/skeleton_dataset/metadata.json")
val_size = int(len(full_dataset) * val_split)
train_size = len(full_dataset) - val_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, drop_last=False, num_workers=2, pin_memory=True)

# Initialize model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = TwoStreamTCN(CTRGCNModel, num_classes=60).to(device)

# Loss, optimizer, scheduler
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)  # Enable label smoothing
optimizer = optim.AdamW(model.parameters(), lr= learning_rate, weight_decay=1e-4)
scheduler = OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch=len(train_loader), epochs=epochs,pct_start=0.3, anneal_strategy='cos')

# %%
print(f"Train dataset size: {len(full_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
# Out:
# Train dataset size: 56715
# Validation dataset size: 11343

# %%
def train(model, loader):
    model.train()
    total_loss, correct = 0.0, 0
    for joint_x, bone_x, y in loader:
        joint_x, bone_x, y = joint_x.to(device), bone_x.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(joint_x, bone_x)
        loss = criterion(out, y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item() * y.size(0)
        correct += (out.argmax(dim=1) == y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)

def evaluate(model, loader):
    model.eval()
    total_loss, correct = 0.0, 0
    with torch.no_grad():
        for joint_x, bone_x, y in loader:
            joint_x, bone_x, y = joint_x.to(device), bone_x.to(device), y.to(device)
            out = model(joint_x, bone_x)
            loss = criterion(out, y)
            total_loss += loss.item() * y.size(0)
            correct += (out.argmax(dim=1) == y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)

# %%
import csv
import os
import numpy as np

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
learning_rates = []

best_val_acc = 0
patience = 20
patience_counter = 0

# --- Setup CSV logging ---
log_file_path = "Chi_training_log.csv"
os.makedirs("logs", exist_ok=True)
log_file = open(log_file_path, mode='w', newline='')
log_writer = csv.writer(log_file)
log_writer.writerow(["Epoch", "Train Loss", "Val Loss", "Train Acc", "Val Acc", "Learning Rate"])

# --- Training loop ---
for epoch in range(epochs):
    train_loss, train_acc = train(model, train_loader)
    val_loss, val_acc = evaluate(model, val_loader)
    scheduler.step()

    # Track metrics
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    learning_rates.append(optimizer.param_groups[0]['lr'])

    # Log to CSV per epoch
    log_writer.writerow([epoch+1, train_loss, val_loss, train_acc, val_acc, learning_rates[-1]])

    # Display
    print(f"📅 Epoch {epoch+1}/{epochs} | "
          f"Train Loss: {train_loss:.4f}, Acc: {train_acc:.4f} | "
          f"Val Loss: {val_loss:.4f}, Acc: {val_acc:.4f}")

    # Save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_ctr_two_stream_model.pth")
        print("✅ Best model saved!")
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("🛑 Early stopping: no improvement after", patience, "epochs.")
            break

# --- Finish ---
log_file.close()
print("🎉 Training complete!")
# Out:
# 📅 Epoch 1/100 | Train Loss: 3.4023, Acc: 0.1663 | Val Loss: 3.1256, Acc: 0.2324
# ✅ Best model saved!
# 📅 Epoch 2/100 | Train Loss: 2.9964, Acc: 0.2722 | Val Loss: 2.9509, Acc: 0.2803
# ✅ Best model saved!
# 📅 Epoch 3/100 | Train Loss: 2.8651, Acc: 0.3110 | Val Loss: 2.8123, Acc: 0.3259
# ✅ Best model saved!
# 📅 Epoch 4/100 | Train Loss: 2.7601, Acc: 0.3491 | Val Loss: 2.8051, Acc: 0.3262
# ✅ Best model saved!
# 📅 Epoch 5/100 | Train Loss: 2.6710, Acc: 0.3718 | Val Loss: 2.7315, Acc: 0.3330
# ✅ Best model saved!
# 📅 Epoch 6/100 | Train Loss: 2.5957, Acc: 0.3971 | Val Loss: 2.5688, Acc: 0.4048
# ✅ Best model saved!
# 📅 Epoch 7/100 | Train Loss: 2.5405, Acc: 0.4151 | Val Loss: 2.5118, Acc: 0.4271
# ✅ Best model saved!
# 📅 Epoch 8/100 | Train Loss: 2.4979, Acc: 0.4296 | Val Loss: 2.4796, Acc: 0.4322
# ✅ Best model saved!
# 📅 Epoch 9/100 | Train Loss: 2.4524, Acc: 0.4414 | Val Loss: 2.4598, Acc: 0.4377
# ✅ Best model saved!
# 📅 Epoch 10/100 | Train Loss: 2.4265, Acc: 0.4521 | Val Loss: 2.4450, Acc: 0.4434
# ✅ Best model saved!
# 📅 Epoch 11/100 | Train Loss: 2.3954, Acc: 0.4606 | Val Loss: 2.4336, Acc: 0.4478
# ✅ Best model saved!
# 📅 Epoch 12/100 | Train Loss: 2.3647, Acc: 0.4751 | Val Loss: 2.3880, Acc: 0.4670
# ✅ Best model saved!
# 📅 Epoch 13/100 | Train Loss: 2.3368, Acc: 0.4828 | Val Loss: 2.3779, Acc: 0.4721
# ✅ Best model saved!
# 📅 Epoch 14/100 | Train Loss: 2.3200, Acc: 0.4888 | Val Loss: 2.3220, Acc: 0.4870
# ✅ Best model saved!
# 📅 Epoch 15/100 | Train Loss: 2.3000, Acc: 0.4911 | Val Loss: 2.3489, Acc: 0.4803
# 📅 Epoch 16/100 | Train Loss: 2.2790, Acc: 0.5042 | Val Loss: 2.3112, Acc: 0.4841
# 📅 Epoch 17/100 | Train Loss: 2.2636, Acc: 0.5076 | Val Loss: 2.2961, Acc: 0.4938
# ✅ Best model saved!
# 📅 Epoch 18/100 | Train Loss: 2.2469, Acc: 0.5128 | Val Loss: 2.2754, Acc: 0.5053
# ✅ Best model saved!
# 📅 Epoch 19/100 | Train Loss: 2.2364, Acc: 0.5159 | Val Loss: 2.2801, Acc: 0.5072
# ✅ Best model saved!
# 📅 Epoch 20/100 | Train Loss: 2.2157, Acc: 0.5227 | Val Loss: 2.2542, Acc: 0.5166
# ✅ Best model saved!
# 📅 Epoch 21/100 | Train Loss: 2.1977, Acc: 0.5277 | Val Loss: 2.2427, Acc: 0.5202
# ✅ Best model saved!
# 📅 Epoch 22/100 | Train Loss: 2.1934, Acc: 0.5288 | Val Loss: 2.2574, Acc: 0.5077
# 📅 Epoch 23/100 | Train Loss: 2.1815, Acc: 0.5319 | Val Loss: 2.2289, Acc: 0.5279
# ✅ Best model saved!
# 📅 Epoch 24/100 | Train Loss: 2.1690, Acc: 0.5372 | Val Loss: 2.2343, Acc: 0.5164
# 📅 Epoch 25/100 | Train Loss: 2.1586, Acc: 0.5416 | Val Loss: 2.2175, Acc: 0.5276
# 📅 Epoch 26/100 | Train Loss: 2.1497, Acc: 0.5448 | Val Loss: 2.1760, Acc: 0.5378
# ✅ Best model saved!
# 📅 Epoch 27/100 | Train Loss: 2.1382, Acc: 0.5478 | Val Loss: 2.1998, Acc: 0.5300
# 📅 Epoch 28/100 | Train Loss: 2.1319, Acc: 0.5482 | Val Loss: 2.2053, Acc: 0.5280
# 📅 Epoch 29/100 | Train Loss: 2.1199, Acc: 0.5555 | Val Loss: 2.1670, Acc: 0.5410
# ✅ Best model saved!
# 📅 Epoch 30/100 | Train Loss: 2.1131, Acc: 0.5573 | Val Loss: 2.2105, Acc: 0.5287
# 📅 Epoch 31/100 | Train Loss: 2.1004, Acc: 0.5609 | Val Loss: 2.1374, Acc: 0.5478
# ✅ Best model saved!
# 📅 Epoch 32/100 | Train Loss: 2.0940, Acc: 0.5623 | Val Loss: 2.1572, Acc: 0.5439
# 📅 Epoch 33/100 | Train Loss: 2.0869, Acc: 0.5673 | Val Loss: 2.1542, Acc: 0.5422
# 📅 Epoch 34/100 | Train Loss: 2.0785, Acc: 0.5678 | Val Loss: 2.1269, Acc: 0.5519
# ✅ Best model saved!
# 📅 Epoch 35/100 | Train Loss: 2.0672, Acc: 0.5747 | Val Loss: 2.1019, Acc: 0.5692
# ✅ Best model saved!
# 📅 Epoch 36/100 | Train Loss: 2.0620, Acc: 0.5760 | Val Loss: 2.1609, Acc: 0.5412
# 📅 Epoch 37/100 | Train Loss: 2.0544, Acc: 0.5760 | Val Loss: 2.1070, Acc: 0.5622
# 📅 Epoch 38/100 | Train Loss: 2.0497, Acc: 0.5761 | Val Loss: 2.1012, Acc: 0.5645
# 📅 Epoch 39/100 | Train Loss: 2.0444, Acc: 0.5799 | Val Loss: 2.0942, Acc: 0.5761
# ✅ Best model saved!
# 📅 Epoch 40/100 | Train Loss: 2.0352, Acc: 0.5839 | Val Loss: 2.1132, Acc: 0.5629
# 📅 Epoch 41/100 | Train Loss: 2.0272, Acc: 0.5872 | Val Loss: 2.0994, Acc: 0.5614
# 📅 Epoch 42/100 | Train Loss: 2.0230, Acc: 0.5873 | Val Loss: 2.0795, Acc: 0.5738
# 📅 Epoch 43/100 | Train Loss: 2.0207, Acc: 0.5881 | Val Loss: 2.1154, Acc: 0.5621
# 📅 Epoch 44/100 | Train Loss: 2.0112, Acc: 0.5906 | Val Loss: 2.0929, Acc: 0.5736
# 📅 Epoch 45/100 | Train Loss: 2.0080, Acc: 0.5915 | Val Loss: 2.0797, Acc: 0.5782
# ✅ Best model saved!
# 📅 Epoch 46/100 | Train Loss: 1.9989, Acc: 0.5956 | Val Loss: 2.0703, Acc: 0.5804
# ✅ Best model saved!
# 📅 Epoch 47/100 | Train Loss: 1.9899, Acc: 0.6007 | Val Loss: 2.0746, Acc: 0.5722
# 📅 Epoch 48/100 | Train Loss: 1.9856, Acc: 0.6010 | Val Loss: 2.0901, Acc: 0.5700
# 📅 Epoch 49/100 | Train Loss: 1.9837, Acc: 0.6017 | Val Loss: 2.0791, Acc: 0.5709
# 📅 Epoch 50/100 | Train Loss: 1.9757, Acc: 0.6045 | Val Loss: 2.0380, Acc: 0.5869
# ✅ Best model saved!
# 📅 Epoch 51/100 | Train Loss: 1.9686, Acc: 0.6072 | Val Loss: 2.0407, Acc: 0.5881
# ✅ Best model saved!
# 📅 Epoch 52/100 | Train Loss: 1.9666, Acc: 0.6071 | Val Loss: 2.0458, Acc: 0.5846
# 📅 Epoch 53/100 | Train Loss: 1.9603, Acc: 0.6095 | Val Loss: 2.0871, Acc: 0.5697
# 📅 Epoch 54/100 | Train Loss: 1.9571, Acc: 0.6080 | Val Loss: 2.0269, Acc: 0.5982
# ✅ Best model saved!
# 📅 Epoch 55/100 | Train Loss: 1.9490, Acc: 0.6101 | Val Loss: 2.0381, Acc: 0.5885
# 📅 Epoch 56/100 | Train Loss: 1.9471, Acc: 0.6132 | Val Loss: 2.0553, Acc: 0.5869
# 📅 Epoch 57/100 | Train Loss: 1.9441, Acc: 0.6147 | Val Loss: 2.0385, Acc: 0.5814
# 📅 Epoch 58/100 | Train Loss: 1.9439, Acc: 0.6143 | Val Loss: 2.0059, Acc: 0.6021
# ✅ Best model saved!
# 📅 Epoch 59/100 | Train Loss: 1.9337, Acc: 0.6191 | Val Loss: 2.0086, Acc: 0.6034
# ✅ Best model saved!
# 📅 Epoch 60/100 | Train Loss: 1.9311, Acc: 0.6207 | Val Loss: 2.0340, Acc: 0.5864
# 📅 Epoch 61/100 | Train Loss: 1.9224, Acc: 0.6217 | Val Loss: 2.0371, Acc: 0.5860
# 📅 Epoch 62/100 | Train Loss: 1.9232, Acc: 0.6197 | Val Loss: 2.0134, Acc: 0.5992
# 📅 Epoch 63/100 | Train Loss: 1.9172, Acc: 0.6242 | Val Loss: 2.0021, Acc: 0.6059
# ✅ Best model saved!
# 📅 Epoch 64/100 | Train Loss: 1.9099, Acc: 0.6261 | Val Loss: 2.0458, Acc: 0.5812
# 📅 Epoch 65/100 | Train Loss: 1.9086, Acc: 0.6266 | Val Loss: 2.0062, Acc: 0.5997
# 📅 Epoch 66/100 | Train Loss: 1.9050, Acc: 0.6271 | Val Loss: 1.9959, Acc: 0.6057
# 📅 Epoch 67/100 | Train Loss: 1.8948, Acc: 0.6312 | Val Loss: 2.0063, Acc: 0.5975
# 📅 Epoch 68/100 | Train Loss: 1.8962, Acc: 0.6295 | Val Loss: 2.0031, Acc: 0.5982
# 📅 Epoch 69/100 | Train Loss: 1.8941, Acc: 0.6319 | Val Loss: 2.0193, Acc: 0.5943
# 📅 Epoch 70/100 | Train Loss: 1.8883, Acc: 0.6340 | Val Loss: 1.9894, Acc: 0.6059
# 📅 Epoch 71/100 | Train Loss: 1.8843, Acc: 0.6353 | Val Loss: 2.0338, Acc: 0.5905
# 📅 Epoch 72/100 | Train Loss: 1.8831, Acc: 0.6342 | Val Loss: 1.9778, Acc: 0.6095
# ✅ Best model saved!
# 📅 Epoch 73/100 | Train Loss: 1.8775, Acc: 0.6367 | Val Loss: 1.9914, Acc: 0.6007
# 📅 Epoch 74/100 | Train Loss: 1.8758, Acc: 0.6377 | Val Loss: 1.9943, Acc: 0.6034
# 📅 Epoch 75/100 | Train Loss: 1.8702, Acc: 0.6393 | Val Loss: 1.9931, Acc: 0.6030
# 📅 Epoch 76/100 | Train Loss: 1.8684, Acc: 0.6396 | Val Loss: 2.0014, Acc: 0.6040
# 📅 Epoch 77/100 | Train Loss: 1.8653, Acc: 0.6405 | Val Loss: 1.9856, Acc: 0.6027
# 📅 Epoch 78/100 | Train Loss: 1.8623, Acc: 0.6430 | Val Loss: 1.9911, Acc: 0.6027
# 📅 Epoch 79/100 | Train Loss: 1.8558, Acc: 0.6454 | Val Loss: 1.9970, Acc: 0.5997
# 📅 Epoch 80/100 | Train Loss: 1.8541, Acc: 0.6452 | Val Loss: 1.9645, Acc: 0.6149
# ✅ Best model saved!
# 📅 Epoch 81/100 | Train Loss: 1.8504, Acc: 0.6486 | Val Loss: 1.9749, Acc: 0.6107
# 📅 Epoch 82/100 | Train Loss: 1.8497, Acc: 0.6469 | Val Loss: 1.9897, Acc: 0.6009
# 📅 Epoch 83/100 | Train Loss: 1.8478, Acc: 0.6471 | Val Loss: 1.9619, Acc: 0.6148
# 📅 Epoch 84/100 | Train Loss: 1.8485, Acc: 0.6458 | Val Loss: 1.9641, Acc: 0.6159
# ✅ Best model saved!
# 📅 Epoch 85/100 | Train Loss: 1.8395, Acc: 0.6493 | Val Loss: 2.0142, Acc: 0.5978
# 📅 Epoch 86/100 | Train Loss: 1.8373, Acc: 0.6495 | Val Loss: 1.9894, Acc: 0.6088
# 📅 Epoch 87/100 | Train Loss: 1.8330, Acc: 0.6539 | Val Loss: 1.9722, Acc: 0.6169
# ✅ Best model saved!
# 📅 Epoch 88/100 | Train Loss: 1.8330, Acc: 0.6531 | Val Loss: 1.9487, Acc: 0.6268
# ✅ Best model saved!
# 📅 Epoch 89/100 | Train Loss: 1.8302, Acc: 0.6525 | Val Loss: 1.9590, Acc: 0.6129
# 📅 Epoch 90/100 | Train Loss: 1.8252, Acc: 0.6533 | Val Loss: 1.9424, Acc: 0.6242
# 📅 Epoch 91/100 | Train Loss: 1.8215, Acc: 0.6587 | Val Loss: 1.9514, Acc: 0.6169
# 📅 Epoch 92/100 | Train Loss: 1.8192, Acc: 0.6584 | Val Loss: 1.9466, Acc: 0.6202
# 📅 Epoch 93/100 | Train Loss: 1.8139, Acc: 0.6612 | Val Loss: 1.9526, Acc: 0.6176
# 📅 Epoch 94/100 | Train Loss: 1.8121, Acc: 0.6590 | Val Loss: 1.9600, Acc: 0.6148
# 📅 Epoch 95/100 | Train Loss: 1.8068, Acc: 0.6590 | Val Loss: 1.9656, Acc: 0.6145
# 📅 Epoch 96/100 | Train Loss: 1.8026, Acc: 0.6628 | Val Loss: 1.9539, Acc: 0.6212
# 📅 Epoch 97/100 | Train Loss: 1.8037, Acc: 0.6626 | Val Loss: 1.9420, Acc: 0.6193
# 📅 Epoch 98/100 | Train Loss: 1.7991, Acc: 0.6657 | Val Loss: 1.9392, Acc: 0.6214
# 📅 Epoch 99/100 | Train Loss: 1.7977, Acc: 0.6655 | Val Loss: 1.9448, Acc: 0.6225
# 📅 Epoch 100/100 | Train Loss: 1.7965, Acc: 0.6669 | Val Loss: 1.9281, Acc: 0.6282
# ✅ Best model saved!
# 🎉 Training complete!

# %% [markdown]
# # **EVALUATION**

# %%
import matplotlib.pyplot as plt

epochs_range = range(1, len(train_losses) + 1)
plt.figure(figsize=(18, 5))

# Loss Curve
plt.subplot(1, 3, 1)
plt.plot(epochs_range, train_losses, marker = 'o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss vs Epoch")
plt.legend()
plt.grid()

# Accuracy Curve
plt.subplot(1, 3, 2)
plt.plot(epochs_range, train_accuracies, label='Train Accuracy', marker='o')
plt.plot(epochs_range, val_accuracies, label='Test Accuracy', marker='x')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train vs Test Accuracy")
plt.legend()
plt.grid()

# Learning Rate Curve
plt.subplot(1, 3, 3)
plt.plot(epochs_range, learning_rates, label='Learning Rate', marker='o')
plt.xlabel("Epoch")
plt.ylabel("LR")
plt.title("Learning Rate vs Epoch")
plt.grid()

plt.tight_layout()
plt.savefig("logs/training_curves.png")
plt.show()
# Out:
# <ipython-input-99-4140630efb73>:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# ✅ NTU60 gesture labels (A001 to A060)
gesture_names = [
    "drink water", "eat meal/snack", "brushing teeth", "brushing hair", "drop",
    "pickup", "throw", "sitting down", "standing up", "clapping",
    "reading", "writing", "tear up paper", "wear jacket", "take off jacket",
    "wear a shoe", "take off a shoe", "wear on glasses", "take off glasses", "put on hat",
    "take off hat", "cheer up", "hand waving", "kicking", "reach into pocket",
    "hopping", "jump up", "make phone call", "play with phone", "typing keyboard",
    "point with finger", "take selfie", "check time", "rub hands", "nod head",
    "shake head", "wipe face", "salute", "palms together", "cross arms (stop)",
    "sneeze/cough", "staggering", "falling", "touch head", "touch chest",
    "touch back", "touch neck", "nausea/vomit", "fan self", "slap/punch other person",
    "kick other person", "push other person", "pat back", "point at other person",
    "hug other person", "give object", "touch other person’s pocket", "handshake",
    "walk towards", "walk away"
]

import torch
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix, # Keep this
    # ConfusionMatrixDisplay, # Not needed for Seaborn plot
    classification_report,
    accuracy_score
)
import seaborn as sns # Add seaborn
import numpy as np   # Add numpy

def get_all_preds_and_labels(model, data_loader):
    """Gets predictions and true labels for a dataset (two-stream version)."""
    model.eval()
    all_preds_list = []
    all_labels_list = []
    device = next(model.parameters()).device

    with torch.no_grad():
        for joint_x, bone_x, labels in data_loader:
            joint_x, bone_x, labels = joint_x.to(device), bone_x.to(device), labels.to(device)

            outputs = model(joint_x, bone_x)
            _, preds = torch.max(outputs, 1)
            all_preds_list.extend(preds.cpu().numpy())
            all_labels_list.extend(labels.cpu().numpy())

    return np.array(all_preds_list), np.array(all_labels_list)

# 1. Get Predictions and Labels (using your function)
# Using names from the second block for clarity
all_preds, all_labels = get_all_preds_and_labels(model, val_loader)

# 2. Ensure gesture_names length matches the number of classes found
# (Important if gesture_names is predefined and might be longer)
unique_labels = np.unique(all_labels)
num_classes = len(unique_labels)

# Make sure gesture_names exists and has the right length
if 'gesture_names' not in locals() or gesture_names is None:
    # Create generic names if not provided
    gesture_names = [f"Class {i}" for i in range(num_classes)]
    print(f"Warning: 'gesture_names' not provided. Using generic names: {gesture_names}")
elif len(gesture_names) < num_classes:
     raise ValueError(f"gesture_names has {len(gesture_names)} elements, but {num_classes} classes were found.")
elif len(gesture_names) > num_classes:
     print(f"Warning: gesture_names has {len(gesture_names)} elements, but only {num_classes} unique classes were found in labels. Trimming gesture_names.")
     gesture_names = gesture_names[:num_classes]


# 3. Calculate Confusion Matrices (normalized and raw)
cm = confusion_matrix(all_labels, all_preds, normalize='true', labels=unique_labels) # Use unique_labels to ensure order if some classes are missing
# raw_cm = confusion_matrix(all_labels, all_preds, labels=unique_labels) # Optional: for counts if needed elsewhere

# 4. Calculate Per-class accuracy
# Diagonal of the normalized confusion matrix represents recall for each class
class_acc = np.diag(cm) * 100 # Renamed to  for clarity

# --- [Previous code: imports, function, get predictions/labels, calculate cm] ---

# 5. Plot Confusion Matrix - ADJUSTED FOR SIZE
plt.figure(figsize=(24, 20))
ax = sns.heatmap(cm, annot=True, fmt=".2f", cmap='Blues',
                 xticklabels=gesture_names, yticklabels=gesture_names,
                 annot_kws={"size": 6}, linewidths=0.3, cbar=True)

# 6. Highlight low-accuracy (low-recall) cells
low_acc_threshold = 50  # percent
for i in range(num_classes):
    acc = cm[i, i] * 100
    if acc < low_acc_threshold:
        ax.add_patch(plt.Rectangle((i, i), 1, 1, fill=False, edgecolor='red', linewidth=2))

plt.title(f"Normalized Confusion Matrix (Low Accuracy Highlighted)") # Slightly larger title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
# You might want to save this large figure instead of just showing it inline
# plt.savefig("large_confusion_matrix.png", dpi=150)
plt.show()

# --- [Optional: Print per-class recall etc.] ---

# 7. Optional: Print per-class recall (accuracy)
print("\nPer-Class Recall (%):")
for i, name in enumerate(gesture_names):
    print(f"{name}: {class_acc[i]:.2f}%")

print(f"\nOverall Accuracy: {accuracy_score(all_labels, all_preds)*100:.2f}%")
# Out:
# Per-Class Recall (%):
# drink water: 67.54%
# eat meal/snack: 51.34%
# brushing teeth: 60.51%
# brushing hair: 54.71%
# drop: 63.04%
# pickup: 77.20%
# throw: 78.19%
# sitting down: 73.21%
# standing up: 86.27%
# clapping: 48.48%
# reading: 35.75%
# writing: 33.13%
# tear up paper: 67.03%
# wear jacket: 92.93%
# take off jacket: 81.82%
# wear a shoe: 42.05%
# take off a shoe: 46.07%
# wear on glasses: 60.33%
# take off glasses: 69.11%
# put on hat: 39.89%
# take off hat: 73.96%
# cheer up: 78.36%
# hand waving: 69.15%
# kicking: 75.00%
# reach into pocket: 65.09%
# hopping: 89.23%
# jump up: 85.86%
# make phone call: 52.02%
# play with phone: 54.84%
# typing keyboard: 51.20%
# point with finger: 50.00%
# take selfie: 70.88%
# check time: 66.32%
# rub hands: 58.29%
# nod head: 80.12%
# shake head: 62.78%
# wipe face: 64.08%
# salute: 75.00%
# palms together: 74.27%
# cross arms (stop): 74.07%
# sneeze/cough: 62.83%
# staggering: 85.38%
# falling: 95.36%
# touch head: 51.08%
# touch chest: 62.00%
# touch back: 50.58%
# touch neck: 50.52%
# nausea/vomit: 71.29%
# fan self: 55.34%
# slap/punch other person: 40.22%
# kick other person: 27.14%
# push other person: 46.27%
# pat back: 29.32%
# point at other person: 53.66%
# hug other person: 61.93%
# give object: 64.68%
# touch other person’s pocket: 29.94%
# handshake: 57.77%
# walk towards: 70.79%
# walk away: 75.83%
#
# Overall Accuracy: 62.41%
